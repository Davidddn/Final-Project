# %%
import numpy as np 
import pandas as pd 
from plotly.offline import iplot, init_notebook_mode
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import os
import glob
from sklearn.model_selection import train_test_split
import seaborn as sns
import datetime

# %%
for dirname, _, filenames in os.walk('archive/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# archive/symbols_valid_meta.csv
# archive/etfs\AAAU.csv
# archive/etfs\AADR.csv
# archive/etfs\AAXJ.csv
# archive/etfs\ABEQ.csv
# archive/etfs\ACES.csv
# archive/etfs\ACIO.csv
# archive/etfs\ACSG.csv
# archive/etfs\ACSI.csv
# archive/etfs\ACT.csv
# archive/etfs\ACWF.csv
# archive/etfs\ACWI.csv
# archive/etfs\ACWV.csv
# archive/etfs\ACWX.csv
# archive/etfs\ADME.csv
# archive/etfs\ADRE.csv
# archive/etfs\AESR.csv
# archive/etfs\AFIF.csv
# archive/etfs\AFK.csv
# archive/etfs\AFLG.csv
# archive/etfs\AFMC.csv
# archive/etfs\AFSM.csv
# archive/etfs\AFTY.csv
# archive/etfs\AGG.csv
# archive/etfs\AGGP.csv
# archive/etfs\AGGY.csv
# archive/etfs\AGND.csv
# archive/etfs\AGQ.csv
# archive/etfs\AGT.csv
# archive/etfs\AGZ.csv
# archive/etfs\AGZD.csv
# archive/etfs\AIA.csv
# archive/etfs\AIEQ.csv
# archive/etfs\AIIQ.csv
# archive/etfs\AIQ.csv
# archive/etfs\AIRR.csv
# archive/etfs\ALFA.csv
# archive/etfs\ALTS.csv
# archive/etfs\ALTY.csv
# archive/etfs\AMCA.csv
# archive/etfs\AMLP.csv
# archive/etfs\AMOM.csv
# archive/etfs\AMZA.csv
# archive/etfs\ANGL.csv
# archive/etfs\AOA.csv
# archive/etfs\AOK.csv
# archive/etfs\AOM.csv
# archive/etfs\AOR.csv
# archive/etfs\ARCM.csv
# archive/etfs\ARGT.csv
# archive/etfs\ARKF.csv
# archive/etfs\ARKG.csv
# archive/etfs\ARKK.csv
# archive/etfs\ARKQ.csv
# archive/etfs\ARKW.csv
# archive/etfs\ARMR.csv
# archive/etfs\ASEA.csv
# archive/etfs\ASET.csv
# archive/etfs\ASHR.csv
# archive/etfs\ASHS.csv
# archive/etfs\ASHX.csv
# archive/etfs\AUSF.csv
# archive/etfs\AVDE.csv
# archive/etfs\AVDV.csv
# archive/etfs\AVEM.csv
# archive/etfs\AVUS.csv
# archive/etfs\AVUV.csv
# archive/etfs\AWAY.csv
# archive/etfs\AWTM.csv
# archive/etfs\AXJL.csv
# archive/etfs\BAB.csv
# archive/etfs\BAPR.csv
# archive/etfs\BATT.csv
# archive/etfs\BAUG.csv
# archive/etfs\BBAX.csv
# archive/etfs\BBC.csv
# archive/etfs\BBCA.csv
# archive/etfs\BBEU.csv
# archive/etfs\BBH.csv
# archive/etfs\BBIN.csv
# archive/etfs\BBJP.csv
# archive/etfs\BBP.csv
# archive/etfs\BBRE.csv
# archive/etfs\BBSA.csv
# archive/etfs\BBUS.csv
# archive/etfs\BCD.csv
# archive/etfs\BCI.csv
# archive/etfs\BDCY.csv
# archive/etfs\BDEC.csv
# archive/etfs\BDRY.csv
# archive/etfs\BFEB.csv
# archive/etfs\BFIT.csv
# archive/etfs\BFOR.csv
# archive/etfs\BGRN.csv
# archive/etfs\BIB.csv
# archive/etfs\BIBL.csv
# archive/etfs\BICK.csv
# archive/etfs\BIL.csv
# archive/etfs\BIS.csv
# archive/etfs\BIV.csv
# archive/etfs\BIZD.csv
# archive/etfs\BJAN.csv
# archive/etfs\BJK.csv
# archive/etfs\BJUL.csv
# archive/etfs\BJUN.csv
# archive/etfs\BKF.csv
# archive/etfs\BKLN.csv
# archive/etfs\BLCN.csv
# archive/etfs\BLES.csv
# archive/etfs\BLHY.csv
# archive/etfs\BLOK.csv
# archive/etfs\BLV.csv
# archive/etfs\BMAR.csv
# archive/etfs\BND.csv
# archive/etfs\BNDC.csv
# archive/etfs\BNDW.csv
# archive/etfs\BNDX.csv
# archive/etfs\BNO.csv
# archive/etfs\BNOV.csv
# archive/etfs\BOCT.csv
# archive/etfs\BOIL.csv
# archive/etfs\BOND.csv
# archive/etfs\BOSS.csv
# archive/etfs\BOTZ.csv
# archive/etfs\BOUT.csv
# archive/etfs\BRF.csv
# archive/etfs\BRZU.csv
# archive/etfs\BSAE.csv
# archive/etfs\BSBE.csv
# archive/etfs\BSCE.csv
# archive/etfs\BSCK.csv
# archive/etfs\BSCL.csv
# archive/etfs\BSCM.csv
# archive/etfs\BSCN.csv
# archive/etfs\BSCO.csv
# archive/etfs\BSCP.csv
# archive/etfs\BSCQ.csv
# archive/etfs\BSCR.csv
# archive/etfs\BSCS.csv
# archive/etfs\BSCT.csv
# archive/etfs\BSDE.csv
# archive/etfs\BSEP.csv
# archive/etfs\BSJK.csv
# archive/etfs\BSJL.csv
# archive/etfs\BSJM.csv
# archive/etfs\BSJN.csv
# archive/etfs\BSJO.csv
# archive/etfs\BSJP.csv
# archive/etfs\BSJQ.csv
# archive/etfs\BSJR.csv
# archive/etfs\BSML.csv
# archive/etfs\BSMM.csv
# archive/etfs\BSMN.csv
# archive/etfs\BSMO.csv
# archive/etfs\BSMP.csv
# archive/etfs\BSMQ.csv
# archive/etfs\BSMR.csv
# archive/etfs\BSMS.csv
# archive/etfs\BSMT.csv
# archive/etfs\BSV.csv
# archive/etfs\BTAL.csv
# archive/etfs\BTEC.csv
# archive/etfs\BTYS.csv
# archive/etfs\BUG.csv
# archive/etfs\BUL.csv
# archive/etfs\BUY.csv
# archive/etfs\BUYN.csv
# archive/etfs\BUYZ.csv
# archive/etfs\BVAL.csv
# archive/etfs\BWX.csv
# archive/etfs\BWZ.csv
# archive/etfs\BYLD.csv
# archive/etfs\BZQ.csv
# archive/etfs\CACG.csv
# archive/etfs\CALF.csv
# archive/etfs\CANE.csv
# archive/etfs\CARZ.csv
# archive/etfs\CATH.csv
# archive/etfs\CBON.csv
# archive/etfs\CCOR.csv
# archive/etfs\CDC.csv
# archive/etfs\CDL.csv
# archive/etfs\CEF.csv
# archive/etfs\CEFS.csv
# archive/etfs\CEMB.csv
# archive/etfs\CEW.csv
# archive/etfs\CEY.csv
# archive/etfs\CEZ.csv
# archive/etfs\CFA.csv
# archive/etfs\CFO.csv
# archive/etfs\CGW.csv
# archive/etfs\CHAD.csv
# archive/etfs\CHAU.csv
# archive/etfs\CHEP.csv
# archive/etfs\CHGX.csv
# archive/etfs\CHIC.csv
# archive/etfs\CHIE.csv
# archive/etfs\CHIH.csv
# archive/etfs\CHII.csv
# archive/etfs\CHIK.csv
# archive/etfs\CHIL.csv
# archive/etfs\CHIM.csv
# archive/etfs\CHIQ.csv
# archive/etfs\CHIR.csv
# archive/etfs\CHIS.csv
# archive/etfs\CHIU.csv
# archive/etfs\CHIX.csv
# archive/etfs\CHNA.csv
# archive/etfs\CIBR.csv
# archive/etfs\CID.csv
# archive/etfs\CIL.csv
# archive/etfs\CIZ.csv
# archive/etfs\CLIX.csv
# archive/etfs\CLOU.csv
# archive/etfs\CLRG.csv
# archive/etfs\CLTL.csv
# archive/etfs\CMBS.csv
# archive/etfs\CMDY.csv
# archive/etfs\CMF.csv
# archive/etfs\CN.csv
# archive/etfs\CNBS.csv
# archive/etfs\CNCR.csv
# archive/etfs\CNRG.csv
# archive/etfs\CNXT.csv
# archive/etfs\CNYA.csv
# archive/etfs\COM.csv
# archive/etfs\COMB.csv
# archive/etfs\COMT.csv
# archive/etfs\COPX.csv
# archive/etfs\CORN.csv
# archive/etfs\CORP.csv
# archive/etfs\COWZ.csv
# archive/etfs\CPER.csv
# archive/etfs\CPI.csv
# archive/etfs\CQQQ.csv
# archive/etfs\CRAK.csv
# archive/etfs\CRBN.csv
# archive/etfs\CROP.csv
# archive/etfs\CSA.csv
# archive/etfs\CSB.csv
# archive/etfs\CSD.csv
# archive/etfs\CSF.csv
# archive/etfs\CSM.csv
# archive/etfs\CSML.csv
# archive/etfs\CURE.csv
# archive/etfs\CUT.csv
# archive/etfs\CVY.csv
# archive/etfs\CWB.csv
# archive/etfs\CWEB.csv
# archive/etfs\CWI.csv
# archive/etfs\CWS.csv
# archive/etfs\CXSE.csv
# archive/etfs\CYB.csv
# archive/etfs\CZA.csv
# archive/etfs\DALI.csv
# archive/etfs\DALT.csv
# archive/etfs\DAUG.csv
# archive/etfs\DAX.csv
# archive/etfs\DBA.csv
# archive/etfs\DBAW.csv
# archive/etfs\DBB.csv
# archive/etfs\DBC.csv
# archive/etfs\DBE.csv
# archive/etfs\DBEF.csv
# archive/etfs\DBEH.csv
# archive/etfs\DBEM.csv
# archive/etfs\DBEU.csv
# archive/etfs\DBEZ.csv
# archive/etfs\DBGR.csv
# archive/etfs\DBJP.csv
# archive/etfs\DBLV.csv
# archive/etfs\DBMF.csv
# archive/etfs\DBO.csv
# archive/etfs\DBP.csv
# archive/etfs\DBS.csv
# archive/etfs\DBV.csv
# archive/etfs\DDG.csv
# archive/etfs\DDIV.csv
# archive/etfs\DDLS.csv
# archive/etfs\DDM.csv
# archive/etfs\DDWM.csv
# archive/etfs\DEEF.csv
# archive/etfs\DEF.csv
# archive/etfs\DEFA.csv
# archive/etfs\DEM.csv
# archive/etfs\DES.csv
# archive/etfs\DEUS.csv
# archive/etfs\DEW.csv
# archive/etfs\DFE.csv
# archive/etfs\DFEB.csv
# archive/etfs\DFEN.csv
# archive/etfs\DFJ.csv
# archive/etfs\DFND.csv
# archive/etfs\DFNL.csv
# archive/etfs\DGL.csv
# archive/etfs\DGRE.csv
# archive/etfs\DGRO.csv
# archive/etfs\DGRS.csv
# archive/etfs\DGRW.csv
# archive/etfs\DGS.csv
# archive/etfs\DGT.csv
# archive/etfs\DHS.csv
# archive/etfs\DIA.csv
# archive/etfs\DIAL.csv
# archive/etfs\DIET.csv
# archive/etfs\DIG.csv
# archive/etfs\DIM.csv
# archive/etfs\DINT.csv
# archive/etfs\DIV.csv
# archive/etfs\DIVA.csv
# archive/etfs\DIVB.csv
# archive/etfs\DIVO.csv
# archive/etfs\DIVY.csv
# archive/etfs\DJCB.csv
# archive/etfs\DJD.csv
# archive/etfs\DLBR.csv
# archive/etfs\DLN.csv
# archive/etfs\DLS.csv
# archive/etfs\DMDV.csv
# archive/etfs\DMRE.csv
# archive/etfs\DMRI.csv
# archive/etfs\DMRL.csv
# archive/etfs\DMRM.csv
# archive/etfs\DMRS.csv
# archive/etfs\DNL.csv
# archive/etfs\DNOV.csv
# archive/etfs\DOG.csv
# archive/etfs\DOGS.csv
# archive/etfs\DOL.csv
# archive/etfs\DON.csv
# archive/etfs\DOO.csv
# archive/etfs\DPST.csv
# archive/etfs\DRIP.csv
# archive/etfs\DRIV.csv
# archive/etfs\DRN.csv
# archive/etfs\DRSK.csv
# archive/etfs\DRV.csv
# archive/etfs\DRW.csv
# archive/etfs\DSI.csv
# archive/etfs\DSTL.csv
# archive/etfs\DTD.csv
# archive/etfs\DTEC.csv
# archive/etfs\DTH.csv
# archive/etfs\DTN.csv
# archive/etfs\DUG.csv
# archive/etfs\DURA.csv
# archive/etfs\DUSA.csv
# archive/etfs\DUSL.csv
# archive/etfs\DUST.csv
# archive/etfs\DVLU.csv
# archive/etfs\DVOL.csv
# archive/etfs\DVOP.csv
# archive/etfs\DVP.csv
# archive/etfs\DVY.csv
# archive/etfs\DVYA.csv
# archive/etfs\DVYE.csv
# archive/etfs\DWAS.csv
# archive/etfs\DWAT.csv
# archive/etfs\DWAW.csv
# archive/etfs\DWCR.csv
# archive/etfs\DWEQ.csv
# archive/etfs\DWFI.csv
# archive/etfs\DWLD.csv
# archive/etfs\DWM.csv
# archive/etfs\DWMC.csv
# archive/etfs\DWMF.csv
# archive/etfs\DWPP.csv
# archive/etfs\DWSH.csv
# archive/etfs\DWT.csv
# archive/etfs\DWUS.csv
# archive/etfs\DWX.csv
# archive/etfs\DXD.csv
# archive/etfs\DXGE.csv
# archive/etfs\DXJ.csv
# archive/etfs\DXJS.csv
# archive/etfs\DYLS.csv
# archive/etfs\DYNF.csv
# archive/etfs\DZK.csv
# archive/etfs\EAGG.csv
# archive/etfs\EASG.csv
# archive/etfs\EASI.csv
# archive/etfs\EBIZ.csv
# archive/etfs\EBND.csv
# archive/etfs\ECH.csv
# archive/etfs\ECLN.csv
# archive/etfs\ECNS.csv
# archive/etfs\ECON.csv
# archive/etfs\ECOW.csv
# archive/etfs\ECOZ.csv
# archive/etfs\EDC.csv
# archive/etfs\EDEN.csv
# archive/etfs\EDIV.csv
# archive/etfs\EDOG.csv
# archive/etfs\EDOW.csv
# archive/etfs\EDV.csv
# archive/etfs\EDZ.csv
# archive/etfs\EELV.csv
# archive/etfs\EEM.csv
# archive/etfs\EEMA.csv
# archive/etfs\EEMD.csv
# archive/etfs\EEMO.csv
# archive/etfs\EEMS.csv
# archive/etfs\EEMV.csv
# archive/etfs\EEMX.csv
# archive/etfs\EES.csv
# archive/etfs\EET.csv
# archive/etfs\EEV.csv
# archive/etfs\EFA.csv
# archive/etfs\EFAD.csv
# archive/etfs\EFAS.csv
# archive/etfs\EFAV.csv
# archive/etfs\EFAX.csv
# archive/etfs\EFG.csv
# archive/etfs\EFNL.csv
# archive/etfs\EFO.csv
# archive/etfs\EFU.csv
# archive/etfs\EFV.csv
# archive/etfs\EFZ.csv
# archive/etfs\EGPT.csv
# archive/etfs\EIDO.csv
# archive/etfs\EINC.csv
# archive/etfs\EIRL.csv
# archive/etfs\EIS.csv
# archive/etfs\EJAN.csv
# archive/etfs\EJUL.csv
# archive/etfs\EKAR.csv
# archive/etfs\ELD.csv
# archive/etfs\EMAG.csv
# archive/etfs\EMB.csv
# archive/etfs\EMBH.csv
# archive/etfs\EMCB.csv
# archive/etfs\EMCG.csv
# archive/etfs\EMDV.csv
# archive/etfs\EMFM.csv
# archive/etfs\EMGF.csv
# archive/etfs\EMHY.csv
# archive/etfs\EMIF.csv
# archive/etfs\EMIH.csv
# archive/etfs\EMLC.csv
# archive/etfs\EMLP.csv
# archive/etfs\EMMF.csv
# archive/etfs\EMNT.csv
# archive/etfs\EMQQ.csv
# archive/etfs\EMSG.csv
# archive/etfs\EMSH.csv
# archive/etfs\EMTL.csv
# archive/etfs\EMTY.csv
# archive/etfs\EMXC.csv
# archive/etfs\ENFR.csv
# archive/etfs\ENOR.csv
# archive/etfs\ENTR.csv
# archive/etfs\ENZL.csv
# archive/etfs\EPHE.csv
# archive/etfs\EPI.csv
# archive/etfs\EPOL.csv
# archive/etfs\EPP.csv
# archive/etfs\EPRF.csv
# archive/etfs\EPS.csv
# archive/etfs\EPU.csv
# archive/etfs\EPV.csv
# archive/etfs\EQAL.csv
# archive/etfs\EQL.csv
# archive/etfs\EQRR.csv
# archive/etfs\EQWL.csv
# archive/etfs\ERM.csv
# archive/etfs\ERSX.csv
# archive/etfs\ERUS.csv
# archive/etfs\ERX.csv
# archive/etfs\ERY.csv
# archive/etfs\ESG.csv
# archive/etfs\ESGD.csv
# archive/etfs\ESGE.csv
# archive/etfs\ESGG.csv
# archive/etfs\ESGN.csv
# archive/etfs\ESGS.csv
# archive/etfs\ESGU.csv
# archive/etfs\ESGV.csv
# archive/etfs\ESML.csv
# archive/etfs\ESNG.csv
# archive/etfs\ESPO.csv
# archive/etfs\ETHO.csv
# archive/etfs\EUDG.csv
# archive/etfs\EUDV.csv
# archive/etfs\EUFN.csv
# archive/etfs\EUM.csv
# archive/etfs\EUMF.csv
# archive/etfs\EUMV.csv
# archive/etfs\EUO.csv
# archive/etfs\EURL.csv
# archive/etfs\EURZ.csv
# archive/etfs\EUSA.csv
# archive/etfs\EUSC.csv
# archive/etfs\EVIX.csv
# archive/etfs\EVX.csv
# archive/etfs\EWA.csv
# archive/etfs\EWC.csv
# archive/etfs\EWCO.csv
# archive/etfs\EWD.csv
# archive/etfs\EWG.csv
# archive/etfs\EWGS.csv
# archive/etfs\EWH.csv
# archive/etfs\EWI.csv
# archive/etfs\EWJ.csv
# archive/etfs\EWJE.csv
# archive/etfs\EWJV.csv
# archive/etfs\EWK.csv
# archive/etfs\EWL.csv
# archive/etfs\EWM.csv
# archive/etfs\EWMC.csv
# archive/etfs\EWN.csv
# archive/etfs\EWO.csv
# archive/etfs\EWP.csv
# archive/etfs\EWQ.csv
# archive/etfs\EWRE.csv
# archive/etfs\EWS.csv
# archive/etfs\EWSC.csv
# archive/etfs\EWT.csv
# archive/etfs\EWU.csv
# archive/etfs\EWUS.csv
# archive/etfs\EWV.csv
# archive/etfs\EWW.csv
# archive/etfs\EWX.csv
# archive/etfs\EWY.csv
# archive/etfs\EWZ.csv
# archive/etfs\EWZS.csv
# archive/etfs\EXI.csv
# archive/etfs\EXIV.csv
# archive/etfs\EYLD.csv
# archive/etfs\EZA.csv
# archive/etfs\EZJ.csv
# archive/etfs\EZM.csv
# archive/etfs\EZU.csv
# archive/etfs\FAAR.csv
# archive/etfs\FAB.csv
# archive/etfs\FAD.csv
# archive/etfs\FALN.csv
# archive/etfs\FAN.csv
# archive/etfs\FAS.csv
# archive/etfs\FAUG.csv
# archive/etfs\FAUS.csv
# archive/etfs\FAZ.csv
# archive/etfs\FBND.csv
# archive/etfs\FBT.csv
# archive/etfs\FBZ.csv
# archive/etfs\FCA.csv
# archive/etfs\FCAL.csv
# archive/etfs\FCAN.csv
# archive/etfs\FCEF.csv
# archive/etfs\FCG.csv
# archive/etfs\FCOM.csv
# archive/etfs\FCOR.csv
# archive/etfs\FCPI.csv
# archive/etfs\FCTR.csv
# archive/etfs\FCVT.csv
# archive/etfs\FDD.csv
# archive/etfs\FDEM.csv
# archive/etfs\FDEV.csv
# archive/etfs\FDG.csv
# archive/etfs\FDHY.csv
# archive/etfs\FDIS.csv
# archive/etfs\FDIV.csv
# archive/etfs\FDL.csv
# archive/etfs\FDLO.csv
# archive/etfs\FDM.csv
# archive/etfs\FDMO.csv
# archive/etfs\FDN.csv
# archive/etfs\FDNI.csv
# archive/etfs\FDRR.csv
# archive/etfs\FDT.csv
# archive/etfs\FDTS.csv
# archive/etfs\FDVV.csv
# archive/etfs\FEM.csv
# archive/etfs\FEMB.csv
# archive/etfs\FEMS.csv
# archive/etfs\FENY.csv
# archive/etfs\FEP.csv
# archive/etfs\FEUZ.csv
# archive/etfs\FEX.csv
# archive/etfs\FEZ.csv
# archive/etfs\FFEB.csv
# archive/etfs\FFHG.csv
# archive/etfs\FFIU.csv
# archive/etfs\FFR.csv
# archive/etfs\FFSG.csv
# archive/etfs\FFTG.csv
# archive/etfs\FFTI.csv
# archive/etfs\FFTY.csv
# archive/etfs\FGD.csv
# archive/etfs\FGM.csv
# archive/etfs\FHK.csv
# archive/etfs\FHLC.csv
# archive/etfs\FIBR.csv
# archive/etfs\FID.csv
# archive/etfs\FIDI.csv
# archive/etfs\FIDU.csv
# archive/etfs\FILL.csv
# archive/etfs\FINX.csv
# archive/etfs\FISR.csv
# archive/etfs\FITE.csv
# archive/etfs\FIVA.csv
# archive/etfs\FIVG.csv
# archive/etfs\FIW.csv
# archive/etfs\FIXD.csv
# archive/etfs\FJNK.csv
# archive/etfs\FJP.csv
# archive/etfs\FKO.csv
# archive/etfs\FKU.csv
# archive/etfs\FLAG.csv
# archive/etfs\FLAU.csv
# archive/etfs\FLAX.csv
# archive/etfs\FLBL.csv
# archive/etfs\FLBR.csv
# archive/etfs\FLCA.csv
# archive/etfs\FLCB.csv
# archive/etfs\FLCH.csv
# archive/etfs\FLCO.csv
# archive/etfs\FLDR.csv
# archive/etfs\FLEE.csv
# archive/etfs\FLEH.csv
# archive/etfs\FLEU.csv
# archive/etfs\FLFR.csv
# archive/etfs\FLGB.csv
# archive/etfs\FLGR.csv
# archive/etfs\FLHK.csv
# archive/etfs\FLHY.csv
# archive/etfs\FLIA.csv
# archive/etfs\FLIN.csv
# archive/etfs\FLIY.csv
# archive/etfs\FLJH.csv
# archive/etfs\FLJP.csv
# archive/etfs\FLKR.csv
# archive/etfs\FLLA.csv
# archive/etfs\FLLV.csv
# archive/etfs\FLM.csv
# archive/etfs\FLMB.csv
# archive/etfs\FLMI.csv
# archive/etfs\FLMX.csv
# archive/etfs\FLN.csv
# archive/etfs\FLOT.csv
# archive/etfs\FLQD.csv
# archive/etfs\FLQE.csv
# archive/etfs\FLQG.csv
# archive/etfs\FLQH.csv
# archive/etfs\FLQL.csv
# archive/etfs\FLQM.csv
# archive/etfs\FLQS.csv
# archive/etfs\FLRN.csv
# archive/etfs\FLRT.csv
# archive/etfs\FLRU.csv
# archive/etfs\FLSA.csv
# archive/etfs\FLSP.csv
# archive/etfs\FLSW.csv
# archive/etfs\FLTB.csv
# archive/etfs\FLTR.csv
# archive/etfs\FLTW.csv
# archive/etfs\FLYT.csv
# archive/etfs\FLZA.csv
# archive/etfs\FM.csv
# archive/etfs\FMAT.csv
# archive/etfs\FMB.csv
# archive/etfs\FMF.csv
# archive/etfs\FMHI.csv
# archive/etfs\FMK.csv
# archive/etfs\FNCL.csv
# archive/etfs\FNDA.csv
# archive/etfs\FNDB.csv
# archive/etfs\FNDC.csv
# archive/etfs\FNDE.csv
# archive/etfs\FNDF.csv
# archive/etfs\FNDX.csv
# archive/etfs\FNGS.csv
# archive/etfs\FNI.csv
# archive/etfs\FNK.csv
# archive/etfs\FNOV.csv
# archive/etfs\FNX.csv
# archive/etfs\FNY.csv
# archive/etfs\FOVL.csv
# archive/etfs\FPA.csv
# archive/etfs\FPE.csv
# archive/etfs\FPEI.csv
# archive/etfs\FPX.csv
# archive/etfs\FPXE.csv
# archive/etfs\FPXI.csv
# archive/etfs\FQAL.csv
# archive/etfs\FRAK.csv
# archive/etfs\FRDM.csv
# archive/etfs\FREL.csv
# archive/etfs\FRI.csv
# archive/etfs\FSMB.csv
# archive/etfs\FSMD.csv
# archive/etfs\FSTA.csv
# archive/etfs\FSZ.csv
# archive/etfs\FTA.csv
# archive/etfs\FTAG.csv
# archive/etfs\FTC.csv
# archive/etfs\FTCS.csv
# archive/etfs\FTEC.csv
# archive/etfs\FTGC.csv
# archive/etfs\FTHI.csv
# archive/etfs\FTLB.csv
# archive/etfs\FTLS.csv
# archive/etfs\FTRI.csv
# archive/etfs\FTSD.csv
# archive/etfs\FTSL.csv
# archive/etfs\FTSM.csv
# archive/etfs\FTXD.csv
# archive/etfs\FTXG.csv
# archive/etfs\FTXH.csv
# archive/etfs\FTXL.csv
# archive/etfs\FTXN.csv
# archive/etfs\FTXO.csv
# archive/etfs\FTXR.csv
# archive/etfs\FUMB.csv
# archive/etfs\FUT.csv
# archive/etfs\FUTY.csv
# archive/etfs\FV.csv
# archive/etfs\FVAL.csv
# archive/etfs\FVC.csv
# archive/etfs\FVD.csv
# archive/etfs\FVL.csv
# archive/etfs\FWDB.csv
# archive/etfs\FXA.csv
# archive/etfs\FXB.csv
# archive/etfs\FXC.csv
# archive/etfs\FXD.csv
# archive/etfs\FXE.csv
# archive/etfs\FXF.csv
# archive/etfs\FXG.csv
# archive/etfs\FXH.csv
# archive/etfs\FXI.csv
# archive/etfs\FXL.csv
# archive/etfs\FXN.csv
# archive/etfs\FXO.csv
# archive/etfs\FXP.csv
# archive/etfs\FXR.csv
# archive/etfs\FXU.csv
# archive/etfs\FXY.csv
# archive/etfs\FXZ.csv
# archive/etfs\FYC.csv
# archive/etfs\FYLD.csv
# archive/etfs\FYT.csv
# archive/etfs\FYX.csv
# archive/etfs\GAA.csv
# archive/etfs\GAL.csv
# archive/etfs\GAMR.csv
# archive/etfs\GBDV.csv
# archive/etfs\GBF.csv
# archive/etfs\GBIL.csv
# archive/etfs\GBUG.csv
# archive/etfs\GBUY.csv
# archive/etfs\GCC.csv
# archive/etfs\GCOW.csv
# archive/etfs\GDAT.csv
# archive/etfs\GDMA.csv
# archive/etfs\GDNA.csv
# archive/etfs\GDVD.csv
# archive/etfs\GDX.csv
# archive/etfs\GDXJ.csv
# archive/etfs\GEM.csv
# archive/etfs\GENY.csv
# archive/etfs\GFIN.csv
# archive/etfs\GHYB.csv
# archive/etfs\GHYG.csv
# archive/etfs\GIGB.csv
# archive/etfs\GIGE.csv
# archive/etfs\GII.csv
# archive/etfs\GLBY.csv
# archive/etfs\GLD.csv
# archive/etfs\GLDM.csv
# archive/etfs\GLIF.csv
# archive/etfs\GLL.csv
# archive/etfs\GLTR.csv
# archive/etfs\GMAN.csv
# archive/etfs\GMF.csv
# archive/etfs\GMOM.csv
# archive/etfs\GNMA.csv
# archive/etfs\GNOM.csv
# archive/etfs\GNR.csv
# archive/etfs\GOAT.csv
# archive/etfs\GOAU.csv
# archive/etfs\GOEX.csv
# archive/etfs\GOVT.csv
# archive/etfs\GQRE.csv
# archive/etfs\GREK.csv
# archive/etfs\GRES.csv
# archive/etfs\GRID.csv
# archive/etfs\GRNB.csv
# archive/etfs\GSEU.csv
# archive/etfs\GSEW.csv
# archive/etfs\GSG.csv
# archive/etfs\GSIE.csv
# archive/etfs\GSJY.csv
# archive/etfs\GSLC.csv
# archive/etfs\GSSC.csv
# archive/etfs\GSST.csv
# archive/etfs\GSY.csv
# archive/etfs\GTIP.csv
# archive/etfs\GTO.csv
# archive/etfs\GUDB.csv
# archive/etfs\GULF.csv
# archive/etfs\GUNR.csv
# archive/etfs\GURU.csv
# archive/etfs\GUSH.csv
# archive/etfs\GVAL.csv
# archive/etfs\GVI.csv
# archive/etfs\GVIP.csv
# archive/etfs\GWX.csv
# archive/etfs\GXC.csv
# archive/etfs\GXF.csv
# archive/etfs\GXG.csv
# archive/etfs\GXTG.csv
# archive/etfs\GYLD.csv
# archive/etfs\HACK.csv
# archive/etfs\HAIL.csv
# archive/etfs\HAP.csv
# archive/etfs\HAUD.csv
# archive/etfs\HAUZ.csv
# archive/etfs\HAWX.csv
# archive/etfs\HCRB.csv
# archive/etfs\HDAW.csv
# archive/etfs\HDEF.csv
# archive/etfs\HDG.csv
# archive/etfs\HDGE.csv
# archive/etfs\HDIV.csv
# archive/etfs\HDLB.csv
# archive/etfs\HDMV.csv
# archive/etfs\HDV.csv
# archive/etfs\HECO.csv
# archive/etfs\HEDJ.csv
# archive/etfs\HEEM.csv
# archive/etfs\HEFA.csv
# archive/etfs\HELX.csv
# archive/etfs\HERD.csv
# archive/etfs\HERO.csv
# archive/etfs\HEWC.csv
# archive/etfs\HEWG.csv
# archive/etfs\HEWI.csv
# archive/etfs\HEWJ.csv
# archive/etfs\HEWL.csv
# archive/etfs\HEWP.csv
# archive/etfs\HEWU.csv
# archive/etfs\HEWW.csv
# archive/etfs\HEWY.csv
# archive/etfs\HEZU.csv
# archive/etfs\HFXE.csv
# archive/etfs\HFXI.csv
# archive/etfs\HFXJ.csv
# archive/etfs\HIBL.csv
# archive/etfs\HIBS.csv
# archive/etfs\HIPS.csv
# archive/etfs\HJPX.csv
# archive/etfs\HLAL.csv
# archive/etfs\HMOP.csv
# archive/etfs\HNDL.csv
# archive/etfs\HOLD.csv
# archive/etfs\HOMZ.csv
# archive/etfs\HSCZ.csv
# archive/etfs\HSPX.csv
# archive/etfs\HSRT.csv
# archive/etfs\HTAB.csv
# archive/etfs\HTEC.csv
# archive/etfs\HTRB.csv
# archive/etfs\HTUS.csv
# archive/etfs\HUSE.csv
# archive/etfs\HUSV.csv
# archive/etfs\HYD.csv
# archive/etfs\HYDB.csv
# archive/etfs\HYDW.csv
# archive/etfs\HYEM.csv
# archive/etfs\HYG.csv
# archive/etfs\HYGH.csv
# archive/etfs\HYGV.csv
# archive/etfs\HYHG.csv
# archive/etfs\HYIH.csv
# archive/etfs\HYLB.csv
# archive/etfs\HYLD.csv
# archive/etfs\HYLS.csv
# archive/etfs\HYLV.csv
# archive/etfs\HYMB.csv
# archive/etfs\HYND.csv
# archive/etfs\HYS.csv
# archive/etfs\HYTR.csv
# archive/etfs\HYUP.csv
# archive/etfs\HYXE.csv
# archive/etfs\HYXU.csv
# archive/etfs\HYZD.csv
# archive/etfs\IAGG.csv
# archive/etfs\IAI.csv
# archive/etfs\IAK.csv
# archive/etfs\IAT.csv
# archive/etfs\IAU.csv
# archive/etfs\IAUF.csv
# archive/etfs\IBB.csv
# archive/etfs\IBCE.csv
# archive/etfs\IBD.csv
# archive/etfs\IBDD.csv
# archive/etfs\IBDL.csv
# archive/etfs\IBDM.csv
# archive/etfs\IBDN.csv
# archive/etfs\IBDO.csv
# archive/etfs\IBDP.csv
# archive/etfs\IBDQ.csv
# archive/etfs\IBDR.csv
# archive/etfs\IBDS.csv
# archive/etfs\IBDT.csv
# archive/etfs\IBDU.csv
# archive/etfs\IBHA.csv
# archive/etfs\IBHB.csv
# archive/etfs\IBHC.csv
# archive/etfs\IBHD.csv
# archive/etfs\IBHE.csv
# archive/etfs\IBMI.csv
# archive/etfs\IBMJ.csv
# archive/etfs\IBMK.csv
# archive/etfs\IBML.csv
# archive/etfs\IBMM.csv
# archive/etfs\IBMN.csv
# archive/etfs\IBMO.csv
# archive/etfs\IBMP.csv
# archive/etfs\IBMQ.csv
# archive/etfs\IBND.csv
# archive/etfs\IBTE.csv
# archive/etfs\IBTF.csv
# archive/etfs\IBTG.csv
# archive/etfs\IBTH.csv
# archive/etfs\IBTI.csv
# archive/etfs\IBTJ.csv
# archive/etfs\IBUY.csv
# archive/etfs\ICF.csv
# archive/etfs\ICLN.csv
# archive/etfs\ICOL.csv
# archive/etfs\ICOW.csv
# archive/etfs\ICSH.csv
# archive/etfs\ICVT.csv
# archive/etfs\IDEV.csv
# archive/etfs\IDHD.csv
# archive/etfs\IDHQ.csv
# archive/etfs\IDIV.csv
# archive/etfs\IDLB.csv
# archive/etfs\IDLV.csv
# archive/etfs\IDMO.csv
# archive/etfs\IDNA.csv
# archive/etfs\IDOG.csv
# archive/etfs\IDRV.csv
# archive/etfs\IDU.csv
# archive/etfs\IDV.csv
# archive/etfs\IDX.csv
# archive/etfs\IDY.csv
# archive/etfs\IECS.csv
# archive/etfs\IEDI.csv
# archive/etfs\IEF.csv
# archive/etfs\IEFA.csv
# archive/etfs\IEFN.csv
# archive/etfs\IEHS.csv
# archive/etfs\IEI.csv
# archive/etfs\IEIH.csv
# archive/etfs\IEME.csv
# archive/etfs\IEMG.csv
# archive/etfs\IEO.csv
# archive/etfs\IETC.csv
# archive/etfs\IEUR.csv
# archive/etfs\IEUS.csv
# archive/etfs\IEV.csv
# archive/etfs\IEZ.csv
# archive/etfs\IFEU.csv
# archive/etfs\IFGL.csv
# archive/etfs\IFLY.csv
# archive/etfs\IFRA.csv
# archive/etfs\IFV.csv
# archive/etfs\IG.csv
# archive/etfs\IGBH.csv
# archive/etfs\IGE.csv
# archive/etfs\IGEB.csv
# archive/etfs\IGF.csv
# archive/etfs\IGHG.csv
# archive/etfs\IGIB.csv
# archive/etfs\IGIH.csv
# archive/etfs\IGLB.csv
# archive/etfs\IGM.csv
# archive/etfs\IGN.csv
# archive/etfs\IGOV.csv
# archive/etfs\IGRO.csv
# archive/etfs\IGSB.csv
# archive/etfs\IGV.csv
# archive/etfs\IHAK.csv
# archive/etfs\IHDG.csv
# archive/etfs\IHE.csv
# archive/etfs\IHF.csv
# archive/etfs\IHI.csv
# archive/etfs\IHY.csv
# archive/etfs\IIGD.csv
# archive/etfs\IIGV.csv
# archive/etfs\IJAN.csv
# archive/etfs\IJH.csv
# archive/etfs\IJJ.csv
# archive/etfs\IJK.csv
# archive/etfs\IJR.csv
# archive/etfs\IJS.csv
# archive/etfs\IJT.csv
# archive/etfs\IJUL.csv
# archive/etfs\ILF.csv
# archive/etfs\ILTB.csv
# archive/etfs\IMOM.csv
# archive/etfs\IMTB.csv
# archive/etfs\IMTM.csv
# archive/etfs\INCO.csv
# archive/etfs\INDA.csv
# archive/etfs\INDL.csv
# archive/etfs\INDS.csv
# archive/etfs\INDY.csv
# archive/etfs\INFR.csv
# archive/etfs\INKM.csv
# archive/etfs\INTF.csv
# archive/etfs\IOO.csv
# archive/etfs\IPAC.csv
# archive/etfs\IPAY.csv
# archive/etfs\IPB.csv
# archive/etfs\IPFF.csv
# archive/etfs\IPKW.csv
# archive/etfs\IPO.csv
# archive/etfs\IPOS.csv
# archive/etfs\IQDE.csv
# archive/etfs\IQDF.csv
# archive/etfs\IQDG.csv
# archive/etfs\IQDY.csv
# archive/etfs\IQIN.csv
# archive/etfs\IQLT.csv
# archive/etfs\IQM.csv
# archive/etfs\IQSI.csv
# archive/etfs\IQSU.csv
# archive/etfs\IRBO.csv
# archive/etfs\ISCF.csv
# archive/etfs\ISDS.csv
# archive/etfs\ISDX.csv
# archive/etfs\ISEM.csv
# archive/etfs\ISHG.csv
# archive/etfs\ISMD.csv
# archive/etfs\ISRA.csv
# archive/etfs\ISTB.csv
# archive/etfs\ISZE.csv
# archive/etfs\ITA.csv
# archive/etfs\ITB.csv
# archive/etfs\ITEQ.csv
# archive/etfs\ITM.csv
# archive/etfs\ITOT.csv
# archive/etfs\IUS.csv
# archive/etfs\IUSB.csv
# archive/etfs\IUSG.csv
# archive/etfs\IUSS.csv
# archive/etfs\IUSV.csv
# archive/etfs\IVAL.csv
# archive/etfs\IVE.csv
# archive/etfs\IVLU.csv
# archive/etfs\IVOG.csv
# archive/etfs\IVOL.csv
# archive/etfs\IVOO.csv
# archive/etfs\IVOV.csv
# archive/etfs\IVV.csv
# archive/etfs\IVW.csv
# archive/etfs\IWB.csv
# archive/etfs\IWC.csv
# archive/etfs\IWD.csv
# archive/etfs\IWF.csv
# archive/etfs\IWL.csv
# archive/etfs\IWM.csv
# archive/etfs\IWN.csv
# archive/etfs\IWO.csv
# archive/etfs\IWP.csv
# archive/etfs\IWR.csv
# archive/etfs\IWS.csv
# archive/etfs\IWV.csv
# archive/etfs\IWX.csv
# archive/etfs\IWY.csv
# archive/etfs\IXC.csv
# archive/etfs\IXG.csv
# archive/etfs\IXJ.csv
# archive/etfs\IXN.csv
# archive/etfs\IXP.csv
# archive/etfs\IXSE.csv
# archive/etfs\IXUS.csv
# archive/etfs\IYC.csv
# archive/etfs\IYE.csv
# archive/etfs\IYF.csv
# archive/etfs\IYG.csv
# archive/etfs\IYH.csv
# archive/etfs\IYJ.csv
# archive/etfs\IYK.csv
# archive/etfs\IYLD.csv
# archive/etfs\IYM.csv
# archive/etfs\IYR.csv
# archive/etfs\IYT.csv
# archive/etfs\IYW.csv
# archive/etfs\IYY.csv
# archive/etfs\IYZ.csv
# archive/etfs\IZRL.csv
# archive/etfs\JAGG.csv
# archive/etfs\JCPB.csv
# archive/etfs\JDIV.csv
# archive/etfs\JDST.csv
# archive/etfs\JETS.csv
# archive/etfs\JHCS.csv
# archive/etfs\JHEM.csv
# archive/etfs\JHMA.csv
# archive/etfs\JHMC.csv
# archive/etfs\JHMD.csv
# archive/etfs\JHME.csv
# archive/etfs\JHMF.csv
# archive/etfs\JHMH.csv
# archive/etfs\JHMI.csv
# archive/etfs\JHML.csv
# archive/etfs\JHMM.csv
# archive/etfs\JHMS.csv
# archive/etfs\JHMT.csv
# archive/etfs\JHMU.csv
# archive/etfs\JHSC.csv
# archive/etfs\JIGB.csv
# archive/etfs\JKD.csv
# archive/etfs\JKE.csv
# archive/etfs\JKF.csv
# archive/etfs\JKG.csv
# archive/etfs\JKH.csv
# archive/etfs\JKI.csv
# archive/etfs\JKJ.csv
# archive/etfs\JKK.csv
# archive/etfs\JKL.csv
# archive/etfs\JMBS.csv
# archive/etfs\JMIN.csv
# archive/etfs\JMOM.csv
# archive/etfs\JMST.csv
# archive/etfs\JMUB.csv
# archive/etfs\JNK.csv
# archive/etfs\JNMF.csv
# archive/etfs\JNUG.csv
# archive/etfs\JOYY.csv
# archive/etfs\JPED.csv
# archive/etfs\JPEM.csv
# archive/etfs\JPEU.csv
# archive/etfs\JPGB.csv
# archive/etfs\JPGE.csv
# archive/etfs\JPHF.csv
# archive/etfs\JPHY.csv
# archive/etfs\JPIN.csv
# archive/etfs\JPLS.csv
# archive/etfs\JPMB.csv
# archive/etfs\JPME.csv
# archive/etfs\JPMF.csv
# archive/etfs\JPMV.csv
# archive/etfs\JPN.csv
# archive/etfs\JPNL.csv
# archive/etfs\JPSE.csv
# archive/etfs\JPST.csv
# archive/etfs\JPUS.csv
# archive/etfs\JPXN.csv
# archive/etfs\JQUA.csv
# archive/etfs\JSMD.csv
# archive/etfs\JSML.csv
# archive/etfs\JUST.csv
# archive/etfs\JVAL.csv
# archive/etfs\JXI.csv
# archive/etfs\KALL.csv
# archive/etfs\KARS.csv
# archive/etfs\KBA.csv
# archive/etfs\KBE.csv
# archive/etfs\KBWB.csv
# archive/etfs\KBWD.csv
# archive/etfs\KBWP.csv
# archive/etfs\KBWR.csv
# archive/etfs\KBWY.csv
# archive/etfs\KCCB.csv
# archive/etfs\KCE.csv
# archive/etfs\KCNY.csv
# archive/etfs\KDFI.csv
# archive/etfs\KEMQ.csv
# archive/etfs\KEMX.csv
# archive/etfs\KFYP.csv
# archive/etfs\KGRN.csv
# archive/etfs\KIE.csv
# archive/etfs\KJAN.csv
# archive/etfs\KLCD.csv
# archive/etfs\KLDW.csv
# archive/etfs\KMED.csv
# archive/etfs\KNG.csv
# archive/etfs\KNOW.csv
# archive/etfs\KOCT.csv
# archive/etfs\KOIN.csv
# archive/etfs\KOL.csv
# archive/etfs\KOLD.csv
# archive/etfs\KOMP.csv
# archive/etfs\KORP.csv
# archive/etfs\KORU.csv
# archive/etfs\KRE.csv
# archive/etfs\KRMA.csv
# archive/etfs\KSA.csv
# archive/etfs\KSCD.csv
# archive/etfs\KURE.csv
# archive/etfs\KWEB.csv
# archive/etfs\KXI.csv
# archive/etfs\LABD.csv
# archive/etfs\LABU.csv
# archive/etfs\LACK.csv
# archive/etfs\LBJ.csv
# archive/etfs\LCR.csv
# archive/etfs\LDEM.csv
# archive/etfs\LDRS.csv
# archive/etfs\LDSF.csv
# archive/etfs\LDUR.csv
# archive/etfs\LEAD.csv
# archive/etfs\LEGR.csv
# archive/etfs\LEMB.csv
# archive/etfs\LEND.csv
# archive/etfs\LFEQ.csv
# archive/etfs\LGH.csv
# archive/etfs\LGLV.csv
# archive/etfs\LGOV.csv
# archive/etfs\LIT.csv
# archive/etfs\LKOR.csv
# archive/etfs\LMBS.csv
# archive/etfs\LMLB.csv
# archive/etfs\LNGR.csv
# archive/etfs\LOUP.csv
# archive/etfs\LOWC.csv
# archive/etfs\LQD.csv
# archive/etfs\LQDH.csv
# archive/etfs\LQDI.csv
# archive/etfs\LRGE.csv
# archive/etfs\LRGF.csv
# archive/etfs\LRNZ.csv
# archive/etfs\LSAF.csv
# archive/etfs\LSLT.csv
# archive/etfs\LSST.csv
# archive/etfs\LTL.csv
# archive/etfs\LTPZ.csv
# archive/etfs\LVHB.csv
# archive/etfs\LVHD.csv
# archive/etfs\LVHE.csv
# archive/etfs\LVHI.csv
# archive/etfs\LVUS.csv
# archive/etfs\MAAX.csv
# archive/etfs\MAGA.csv
# archive/etfs\MARB.csv
# archive/etfs\MBB.csv
# archive/etfs\MBSD.csv
# archive/etfs\MCEF.csv
# archive/etfs\MCHI.csv
# archive/etfs\MCRO.csv
# archive/etfs\MDIV.csv
# archive/etfs\MDY.csv
# archive/etfs\MDYG.csv
# archive/etfs\MDYV.csv
# archive/etfs\MEAR.csv
# archive/etfs\MEXX.csv
# archive/etfs\MFDX.csv
# archive/etfs\MFEM.csv
# archive/etfs\MFMS.csv
# archive/etfs\MFUS.csv
# archive/etfs\MGC.csv
# archive/etfs\MGK.csv
# archive/etfs\MGV.csv
# archive/etfs\MIDF.csv
# archive/etfs\MIDU.csv
# archive/etfs\MILN.csv
# archive/etfs\MINC.csv
# archive/etfs\MINT.csv
# archive/etfs\MJ.csv
# archive/etfs\MJJ.csv
# archive/etfs\MJO.csv
# archive/etfs\MLN.csv
# archive/etfs\MLPA.csv
# archive/etfs\MLPX.csv
# archive/etfs\MLTI.csv
# archive/etfs\MMIN.csv
# archive/etfs\MMIT.csv
# archive/etfs\MMTM.csv
# archive/etfs\MNA.csv
# archive/etfs\MOAT.csv
# archive/etfs\MOM.csv
# archive/etfs\MOO.csv
# archive/etfs\MORT.csv
# archive/etfs\MOTI.csv
# archive/etfs\MOTO.csv
# archive/etfs\MRGR.csv
# archive/etfs\MSUS.csv
# archive/etfs\MTGP.csv
# archive/etfs\MTUM.csv
# archive/etfs\MUB.csv
# archive/etfs\MUNI.csv
# archive/etfs\MUST.csv
# archive/etfs\MUTE.csv
# archive/etfs\MVIN.csv
# archive/etfs\MVV.csv
# archive/etfs\MXDE.csv
# archive/etfs\MXDU.csv
# archive/etfs\MXI.csv
# archive/etfs\MYY.csv
# archive/etfs\MZZ.csv
# archive/etfs\NACP.csv
# archive/etfs\NAIL.csv
# archive/etfs\NANR.csv
# archive/etfs\NEAR.csv
# archive/etfs\NEED.csv
# archive/etfs\NERD.csv
# archive/etfs\NETL.csv
# archive/etfs\NFLT.csv
# archive/etfs\NFRA.csv
# archive/etfs\NFTY.csv
# archive/etfs\NGE.csv
# archive/etfs\NJAN.csv
# archive/etfs\NLR.csv
# archive/etfs\NOBL.csv
# archive/etfs\NOCT.csv
# archive/etfs\NORW.csv
# archive/etfs\NTSX.csv
# archive/etfs\NUAG.csv
# archive/etfs\NUBD.csv
# archive/etfs\NUDM.csv
# archive/etfs\NUEM.csv
# archive/etfs\NUGT.csv
# archive/etfs\NUHY.csv
# archive/etfs\NULC.csv
# archive/etfs\NULG.csv
# archive/etfs\NULV.csv
# archive/etfs\NUMG.csv
# archive/etfs\NUMV.csv
# archive/etfs\NURE.csv
# archive/etfs\NUSA.csv
# archive/etfs\NUSC.csv
# archive/etfs\NUSI.csv
# archive/etfs\NXTG.csv
# archive/etfs\NYF.csv
# archive/etfs\OBOR.csv
# archive/etfs\OCIO.csv
# archive/etfs\OEF.csv
# archive/etfs\OEUR.csv
# archive/etfs\OGIG.csv
# archive/etfs\OIH.csv
# archive/etfs\OIL.csv
# archive/etfs\OILK.csv
# archive/etfs\OLD.csv
# archive/etfs\OMFL.csv
# archive/etfs\OMFS.csv
# archive/etfs\ONEO.csv
# archive/etfs\ONEQ.csv
# archive/etfs\ONEV.csv
# archive/etfs\ONEY.csv
# archive/etfs\ONLN.csv
# archive/etfs\OPER.csv
# archive/etfs\OSCV.csv
# archive/etfs\OUNZ.csv
# archive/etfs\OUSA.csv
# archive/etfs\OUSM.csv
# archive/etfs\OVB.csv
# archive/etfs\OVF.csv
# archive/etfs\OVL.csv
# archive/etfs\OVM.csv
# archive/etfs\OVS.csv
# archive/etfs\PACA.csv
# archive/etfs\PAK.csv
# archive/etfs\PALL.csv
# archive/etfs\PAPR.csv
# archive/etfs\PASS.csv
# archive/etfs\PAUG.csv
# archive/etfs\PAVE.csv
# archive/etfs\PAWZ.csv
# archive/etfs\PBD.csv
# archive/etfs\PBDM.csv
# archive/etfs\PBE.csv
# archive/etfs\PBEE.csv
# archive/etfs\PBJ.csv
# archive/etfs\PBND.csv
# archive/etfs\PBP.csv
# archive/etfs\PBS.csv
# archive/etfs\PBSM.csv
# archive/etfs\PBTP.csv
# archive/etfs\PBUS.csv
# archive/etfs\PBW.csv
# archive/etfs\PCEF.csv
# archive/etfs\PCY.csv
# archive/etfs\PDBC.csv
# archive/etfs\PDEC.csv
# archive/etfs\PDEV.csv
# archive/etfs\PDN.csv
# archive/etfs\PDP.csv
# archive/etfs\PEJ.csv
# archive/etfs\PEK.csv
# archive/etfs\PEX.csv
# archive/etfs\PEXL.csv
# archive/etfs\PEY.csv
# archive/etfs\PEZ.csv
# archive/etfs\PFEB.csv
# archive/etfs\PFF.csv
# archive/etfs\PFFA.csv
# archive/etfs\PFFD.csv
# archive/etfs\PFFR.csv
# archive/etfs\PFI.csv
# archive/etfs\PFIG.csv
# archive/etfs\PFLD.csv
# archive/etfs\PFM.csv
# archive/etfs\PFXF.csv
# archive/etfs\PGAL.csv
# archive/etfs\PGF.csv
# archive/etfs\PGHY.csv
# archive/etfs\PGJ.csv
# archive/etfs\PGX.csv
# archive/etfs\PHB.csv
# archive/etfs\PHDG.csv
# archive/etfs\PHO.csv
# archive/etfs\PHYL.csv
# archive/etfs\PHYS.csv
# archive/etfs\PICB.csv
# archive/etfs\PICK.csv
# archive/etfs\PID.csv
# archive/etfs\PIE.csv
# archive/etfs\PILL.csv
# archive/etfs\PIN.csv
# archive/etfs\PIO.csv
# archive/etfs\PIZ.csv
# archive/etfs\PJAN.csv
# archive/etfs\PJP.csv
# archive/etfs\PJUL.csv
# archive/etfs\PJUN.csv
# archive/etfs\PKB.csv
# archive/etfs\PKW.csv
# archive/etfs\PLAT.csv
# archive/etfs\PLC.csv
# archive/etfs\PLCY.csv
# archive/etfs\PLTM.csv
# archive/etfs\PLW.csv
# archive/etfs\PMAR.csv
# archive/etfs\PMOM.csv
# archive/etfs\PNOV.csv
# archive/etfs\PNQI.csv
# archive/etfs\POCT.csv
# archive/etfs\POTX.csv
# archive/etfs\PPA.csv
# archive/etfs\PPDM.csv
# archive/etfs\PPEM.csv
# archive/etfs\PPH.csv
# archive/etfs\PPLC.csv
# archive/etfs\PPLT.csv
# archive/etfs\PPMC.csv
# archive/etfs\PPSC.csv
# archive/etfs\PPTY.csv
# archive/etfs\PQIN.csv
# archive/etfs\PQLC.csv
# archive/etfs\PQSG.csv
# archive/etfs\PQSV.csv
# archive/etfs\PREF.csv
# archive/etfs\PRF.csv
# archive/etfs\PRFZ.csv
# archive/etfs\PRN.csv
# archive/etfs\PRNT.csv
# archive/etfs\PSC.csv
# archive/etfs\PSCC.csv
# archive/etfs\PSCD.csv
# archive/etfs\PSCE.csv
# archive/etfs\PSCF.csv
# archive/etfs\PSCH.csv
# archive/etfs\PSCI.csv
# archive/etfs\PSCM.csv
# archive/etfs\PSCT.csv
# archive/etfs\PSCU.csv
# archive/etfs\PSEP.csv
# archive/etfs\PSET.csv
# archive/etfs\PSI.csv
# archive/etfs\PSJ.csv
# archive/etfs\PSK.csv
# archive/etfs\PSL.csv
# archive/etfs\PSLV.csv
# archive/etfs\PSM.csv
# archive/etfs\PSMB.csv
# archive/etfs\PSMC.csv
# archive/etfs\PSMG.csv
# archive/etfs\PSMM.csv
# archive/etfs\PSP.csv
# archive/etfs\PSQ.csv
# archive/etfs\PSR.csv
# archive/etfs\PST.csv
# archive/etfs\PTBD.csv
# archive/etfs\PTEU.csv
# archive/etfs\PTF.csv
# archive/etfs\PTH.csv
# archive/etfs\PTIN.csv
# archive/etfs\PTLC.csv
# archive/etfs\PTMC.csv
# archive/etfs\PTNQ.csv
# archive/etfs\PUI.csv
# archive/etfs\PULS.csv
# archive/etfs\PUTW.csv
# archive/etfs\PVAL.csv
# archive/etfs\PVI.csv
# archive/etfs\PWB.csv
# archive/etfs\PWC.csv
# archive/etfs\PWS.csv
# archive/etfs\PWV.csv
# archive/etfs\PWZ.csv
# archive/etfs\PXE.csv
# archive/etfs\PXF.csv
# archive/etfs\PXH.csv
# archive/etfs\PXI.csv
# archive/etfs\PXJ.csv
# archive/etfs\PXQ.csv
# archive/etfs\PY.csv
# archive/etfs\PYZ.csv
# archive/etfs\PZA.csv
# archive/etfs\PZD.csv
# archive/etfs\PZT.csv
# archive/etfs\QABA.csv
# archive/etfs\QAI.csv
# archive/etfs\QARP.csv
# archive/etfs\QAT.csv
# archive/etfs\QCLN.csv
# archive/etfs\QDEF.csv
# archive/etfs\QDF.csv
# archive/etfs\QDIV.csv
# archive/etfs\QDYN.csv
# archive/etfs\QED.csv
# archive/etfs\QEFA.csv
# archive/etfs\QEMM.csv
# archive/etfs\QGRO.csv
# archive/etfs\QGTA.csv
# archive/etfs\QID.csv
# archive/etfs\QINT.csv
# archive/etfs\QLC.csv
# archive/etfs\QLD.csv
# archive/etfs\QLS.csv
# archive/etfs\QLTA.csv
# archive/etfs\QLV.csv
# archive/etfs\QLVD.csv
# archive/etfs\QLVE.csv
# archive/etfs\QMJ.csv
# archive/etfs\QMN.csv
# archive/etfs\QMOM.csv
# archive/etfs\QQEW.csv
# archive/etfs\QQH.csv
# archive/etfs\QQQ.csv
# archive/etfs\QQQE.csv
# archive/etfs\QQXT.csv
# archive/etfs\QRFT.csv
# archive/etfs\QSY.csv
# archive/etfs\QTEC.csv
# archive/etfs\QTUM.csv
# archive/etfs\QUAL.csv
# archive/etfs\QUS.csv
# archive/etfs\QVAL.csv
# archive/etfs\QVM.csv
# archive/etfs\QWLD.csv
# archive/etfs\QYLD.csv
# archive/etfs\RAAX.csv
# archive/etfs\RAFE.csv
# archive/etfs\RALS.csv
# archive/etfs\RAVI.csv
# archive/etfs\RBIN.csv
# archive/etfs\RBUS.csv
# archive/etfs\RCD.csv
# archive/etfs\RDIV.csv
# archive/etfs\RDOG.csv
# archive/etfs\RDVY.csv
# archive/etfs\RECS.csv
# archive/etfs\REET.csv
# archive/etfs\REGL.csv
# archive/etfs\REK.csv
# archive/etfs\REM.csv
# archive/etfs\REMX.csv
# archive/etfs\RESD.csv
# archive/etfs\RESE.csv
# archive/etfs\RETL.csv
# archive/etfs\REVS.csv
# archive/etfs\REW.csv
# archive/etfs\REZ.csv
# archive/etfs\RFAP.csv
# archive/etfs\RFCI.csv
# archive/etfs\RFDA.csv
# archive/etfs\RFDI.csv
# archive/etfs\RFEM.csv
# archive/etfs\RFEU.csv
# archive/etfs\RFFC.csv
# archive/etfs\RFG.csv
# archive/etfs\RFUN.csv
# archive/etfs\RFV.csv
# archive/etfs\RGI.csv
# archive/etfs\RHS.csv
# archive/etfs\RIGS.csv
# archive/etfs\RINF.csv
# archive/etfs\RING.csv
# archive/etfs\RISE.csv
# archive/etfs\RLY.csv
# archive/etfs\RNDM.csv
# archive/etfs\RNDV.csv
# archive/etfs\RNEM.csv
# archive/etfs\RNLC.csv
# archive/etfs\RNMC.csv
# archive/etfs\RNSC.csv
# archive/etfs\ROAM.csv
# archive/etfs\ROBO.csv
# archive/etfs\ROBT.csv
# archive/etfs\RODE.csv
# archive/etfs\RODM.csv
# archive/etfs\ROKT.csv
# archive/etfs\ROM.csv
# archive/etfs\ROMO.csv
# archive/etfs\ROOF.csv
# archive/etfs\RORE.csv
# archive/etfs\ROSC.csv
# archive/etfs\ROUS.csv
# archive/etfs\RPAR.csv
# archive/etfs\RPG.csv
# archive/etfs\RPV.csv
# archive/etfs\RSP.csv
# archive/etfs\RSX.csv
# archive/etfs\RSXJ.csv
# archive/etfs\RTH.csv
# archive/etfs\RTL.csv
# archive/etfs\RTM.csv
# archive/etfs\RUSL.csv
# archive/etfs\RVNU.csv
# archive/etfs\RVRS.csv
# archive/etfs\RWCD.csv
# archive/etfs\RWDC.csv
# archive/etfs\RWDE.csv
# archive/etfs\RWED.csv
# archive/etfs\RWGV.csv
# archive/etfs\RWIU.csv
# archive/etfs\RWJ.csv
# archive/etfs\RWK.csv
# archive/etfs\RWL.csv
# archive/etfs\RWLS.csv
# archive/etfs\RWM.csv
# archive/etfs\RWO.csv
# archive/etfs\RWR.csv
# archive/etfs\RWSL.csv
# archive/etfs\RWUI.csv
# archive/etfs\RWVG.csv
# archive/etfs\RWX.csv
# archive/etfs\RXD.csv
# archive/etfs\RXI.csv
# archive/etfs\RXL.csv
# archive/etfs\RYE.csv
# archive/etfs\RYF.csv
# archive/etfs\RYH.csv
# archive/etfs\RYJ.csv
# archive/etfs\RYLD.csv
# archive/etfs\RYT.csv
# archive/etfs\RYU.csv
# archive/etfs\RYZZ.csv
# archive/etfs\RZG.csv
# archive/etfs\RZV.csv
# archive/etfs\SAA.csv
# archive/etfs\SBB.csv
# archive/etfs\SBIO.csv
# archive/etfs\SBM.csv
# archive/etfs\SCAP.csv
# archive/etfs\SCC.csv
# archive/etfs\SCHA.csv
# archive/etfs\SCHB.csv
# archive/etfs\SCHC.csv
# archive/etfs\SCHD.csv
# archive/etfs\SCHE.csv
# archive/etfs\SCHF.csv
# archive/etfs\SCHG.csv
# archive/etfs\SCHH.csv
# archive/etfs\SCHI.csv
# archive/etfs\SCHJ.csv
# archive/etfs\SCHK.csv
# archive/etfs\SCHM.csv
# archive/etfs\SCHO.csv
# archive/etfs\SCHP.csv
# archive/etfs\SCHQ.csv
# archive/etfs\SCHR.csv
# archive/etfs\SCHV.csv
# archive/etfs\SCHX.csv
# archive/etfs\SCHZ.csv
# archive/etfs\SCID.csv
# archive/etfs\SCIF.csv
# archive/etfs\SCIJ.csv
# archive/etfs\SCIU.csv
# archive/etfs\SCIX.csv
# archive/etfs\SCJ.csv
# archive/etfs\SCO.csv
# archive/etfs\SCZ.csv
# archive/etfs\SDAG.csv
# archive/etfs\SDCI.csv
# archive/etfs\SDD.csv
# archive/etfs\SDEM.csv
# archive/etfs\SDG.csv
# archive/etfs\SDGA.csv
# archive/etfs\SDIV.csv
# archive/etfs\SDOG.csv
# archive/etfs\SDOW.csv
# archive/etfs\SDP.csv
# archive/etfs\SDS.csv
# archive/etfs\SDVY.csv
# archive/etfs\SDY.csv
# archive/etfs\SECT.csv
# archive/etfs\SEF.csv
# archive/etfs\SEIX.csv
# archive/etfs\SFHY.csv
# archive/etfs\SFIG.csv
# archive/etfs\SFY.csv
# archive/etfs\SFYF.csv
# archive/etfs\SFYX.csv
# archive/etfs\SGDJ.csv
# archive/etfs\SGDM.csv
# archive/etfs\SGOL.csv
# archive/etfs\SH.csv
# archive/etfs\SHAG.csv
# archive/etfs\SHE.csv
# archive/etfs\SHM.csv
# archive/etfs\SHV.csv
# archive/etfs\SHY.csv
# archive/etfs\SHYD.csv
# archive/etfs\SHYG.csv
# archive/etfs\SHYL.csv
# archive/etfs\SIJ.csv
# archive/etfs\SIL.csv
# archive/etfs\SILJ.csv
# archive/etfs\SIMS.csv
# archive/etfs\SIVR.csv
# archive/etfs\SIZE.csv
# archive/etfs\SJB.csv
# archive/etfs\SJNK.csv
# archive/etfs\SKF.csv
# archive/etfs\SKOR.csv
# archive/etfs\SKYY.csv
# archive/etfs\SLQD.csv
# archive/etfs\SLT.csv
# archive/etfs\SLV.csv
# archive/etfs\SLVP.csv
# archive/etfs\SLX.csv
# archive/etfs\SLY.csv
# archive/etfs\SLYG.csv
# archive/etfs\SLYV.csv
# archive/etfs\SMB.csv
# archive/etfs\SMCP.csv
# archive/etfs\SMDD.csv
# archive/etfs\SMDV.csv
# archive/etfs\SMDY.csv
# archive/etfs\SMEZ.csv
# archive/etfs\SMH.csv
# archive/etfs\SMIN.csv
# archive/etfs\SMLF.csv
# archive/etfs\SMLL.csv
# archive/etfs\SMLV.csv
# archive/etfs\SMMD.csv
# archive/etfs\SMMU.csv
# archive/etfs\SMMV.csv
# archive/etfs\SMN.csv
# archive/etfs\SMOG.csv
# archive/etfs\SNLN.csv
# archive/etfs\SNPE.csv
# archive/etfs\SNSR.csv
# archive/etfs\SNUG.csv
# archive/etfs\SOCL.csv
# archive/etfs\SOIL.csv
# archive/etfs\SOVB.csv
# archive/etfs\SOXL.csv
# archive/etfs\SOXS.csv
# archive/etfs\SOXX.csv
# archive/etfs\SOYB.csv
# archive/etfs\SPAB.csv
# archive/etfs\SPBO.csv
# archive/etfs\SPDN.csv
# archive/etfs\SPDV.csv
# archive/etfs\SPDW.csv
# archive/etfs\SPEM.csv
# archive/etfs\SPEU.csv
# archive/etfs\SPFF.csv
# archive/etfs\SPGM.csv
# archive/etfs\SPGP.csv
# archive/etfs\SPHB.csv
# archive/etfs\SPHD.csv
# archive/etfs\SPHQ.csv
# archive/etfs\SPHY.csv
# archive/etfs\SPIB.csv
# archive/etfs\SPIP.csv
# archive/etfs\SPLB.csv
# archive/etfs\SPLG.csv
# archive/etfs\SPLV.csv
# archive/etfs\SPMB.csv
# archive/etfs\SPMD.csv
# archive/etfs\SPMO.csv
# archive/etfs\SPMV.csv
# archive/etfs\SPPP.csv
# archive/etfs\SPSB.csv
# archive/etfs\SPSK.csv
# archive/etfs\SPSM.csv
# archive/etfs\SPTI.csv
# archive/etfs\SPTL.csv
# archive/etfs\SPTM.csv
# archive/etfs\SPTS.csv
# archive/etfs\SPUS.csv
# archive/etfs\SPUU.csv
# archive/etfs\SPVM.csv
# archive/etfs\SPVU.csv
# archive/etfs\SPXB.csv
# archive/etfs\SPXE.csv
# archive/etfs\SPXL.csv
# archive/etfs\SPXN.csv
# archive/etfs\SPXS.csv
# archive/etfs\SPXT.csv
# archive/etfs\SPXU.csv
# archive/etfs\SPXV.csv
# archive/etfs\SPY.csv
# archive/etfs\SPYB.csv
# archive/etfs\SPYD.csv
# archive/etfs\SPYG.csv
# archive/etfs\SPYV.csv
# archive/etfs\SPYX.csv
# archive/etfs\SQLV.csv
# archive/etfs\SQQQ.csv
# archive/etfs\SRET.csv
# archive/etfs\SRLN.csv
# archive/etfs\SRS.csv
# archive/etfs\SRTY.csv
# archive/etfs\SRVR.csv
# archive/etfs\SSG.csv
# archive/etfs\SSO.csv
# archive/etfs\SSPY.csv
# archive/etfs\SSUS.csv
# archive/etfs\STIP.csv
# archive/etfs\STLG.csv
# archive/etfs\STLV.csv
# archive/etfs\STOT.csv
# archive/etfs\STPZ.csv
# archive/etfs\SUB.csv
# archive/etfs\SUSA.csv
# archive/etfs\SUSB.csv
# archive/etfs\SUSC.csv
# archive/etfs\SUSL.csv
# archive/etfs\SVXY.csv
# archive/etfs\SWAN.csv
# archive/etfs\SYE.csv
# archive/etfs\SYG.csv
# archive/etfs\SYLD.csv
# archive/etfs\SYV.csv
# archive/etfs\SZK.csv
# archive/etfs\SZNE.csv
# archive/etfs\TAGS.csv
# archive/etfs\TAIL.csv
# archive/etfs\TAN.csv
# archive/etfs\TAWK.csv
# archive/etfs\TAXF.csv
# archive/etfs\TBF.csv
# archive/etfs\TBLU.csv
# archive/etfs\TBND.csv
# archive/etfs\TBT.csv
# archive/etfs\TBX.csv
# archive/etfs\TCTL.csv
# archive/etfs\TDIV.csv
# archive/etfs\TDTF.csv
# archive/etfs\TDTT.csv
# archive/etfs\TDV.csv
# archive/etfs\TECB.csv
# archive/etfs\TECL.csv
# archive/etfs\TECS.csv
# archive/etfs\TERM.csv
# archive/etfs\TFI.csv
# archive/etfs\TFIV.csv
# archive/etfs\TFLO.csv
# archive/etfs\TFLT.csv
# archive/etfs\THCX.csv
# archive/etfs\THD.csv
# archive/etfs\TILT.csv
# archive/etfs\TIP.csv
# archive/etfs\TIPX.csv
# archive/etfs\TIPZ.csv
# archive/etfs\TLDH.csv
# archive/etfs\TLEH.csv
# archive/etfs\TLH.csv
# archive/etfs\TLT.csv
# archive/etfs\TLTD.csv
# archive/etfs\TLTE.csv
# archive/etfs\TMDV.csv
# archive/etfs\TMF.csv
# archive/etfs\TMFC.csv
# archive/etfs\TMV.csv
# archive/etfs\TNA.csv
# archive/etfs\TOK.csv
# archive/etfs\TOKE.csv
# archive/etfs\TOLZ.csv
# archive/etfs\TOTL.csv
# archive/etfs\TPAY.csv
# archive/etfs\TPHD.csv
# archive/etfs\TPIF.csv
# archive/etfs\TPLC.csv
# archive/etfs\TPOR.csv
# archive/etfs\TPSC.csv
# archive/etfs\TPYP.csv
# archive/etfs\TQQQ.csv
# archive/etfs\TRND.csv
# archive/etfs\TRTY.csv
# archive/etfs\TTAC.csv
# archive/etfs\TTAI.csv
# archive/etfs\TTT.csv
# archive/etfs\TTTN.csv
# archive/etfs\TUR.csv
# archive/etfs\TUSA.csv
# archive/etfs\TWM.csv
# archive/etfs\TYBS.csv
# archive/etfs\TYD.csv
# archive/etfs\TYO.csv
# archive/etfs\TZA.csv
# archive/etfs\UAE.csv
# archive/etfs\UAPR.csv
# archive/etfs\UAUG.csv
# archive/etfs\UBOT.csv
# archive/etfs\UBR.csv
# archive/etfs\UBT.csv
# archive/etfs\UCC.csv
# archive/etfs\UCO.csv
# archive/etfs\UCON.csv
# archive/etfs\UDEC.csv
# archive/etfs\UDN.csv
# archive/etfs\UDOW.csv
# archive/etfs\UEVM.csv
# archive/etfs\UFEB.csv
# archive/etfs\UFO.csv
# archive/etfs\UGA.csv
# archive/etfs\UGE.csv
# archive/etfs\UGL.csv
# archive/etfs\UITB.csv
# archive/etfs\UIVM.csv
# archive/etfs\UJAN.csv
# archive/etfs\UJB.csv
# archive/etfs\UJUL.csv
# archive/etfs\UJUN.csv
# archive/etfs\ULBR.csv
# archive/etfs\ULE.csv
# archive/etfs\ULST.csv
# archive/etfs\ULTR.csv
# archive/etfs\ULVM.csv
# archive/etfs\UMAR.csv
# archive/etfs\UMDD.csv
# archive/etfs\UNG.csv
# archive/etfs\UNL.csv
# archive/etfs\UNOV.csv
# archive/etfs\UOCT.csv
# archive/etfs\UPRO.csv
# archive/etfs\UPV.csv
# archive/etfs\UPW.csv
# archive/etfs\URA.csv
# archive/etfs\URE.csv
# archive/etfs\URNM.csv
# archive/etfs\URTH.csv
# archive/etfs\URTY.csv
# archive/etfs\USAI.csv
# archive/etfs\USCI.csv
# archive/etfs\USD.csv
# archive/etfs\USDU.csv
# archive/etfs\USDY.csv
# archive/etfs\USEP.csv
# archive/etfs\USEQ.csv
# archive/etfs\USFR.csv
# archive/etfs\USHG.csv
# archive/etfs\USHY.csv
# archive/etfs\USI.csv
# archive/etfs\USIG.csv
# archive/etfs\USL.csv
# archive/etfs\USLB.csv
# archive/etfs\USMC.csv
# archive/etfs\USMF.csv
# archive/etfs\USMV.csv
# archive/etfs\USO.csv
# archive/etfs\USRT.csv
# archive/etfs\USSG.csv
# archive/etfs\UST.csv
# archive/etfs\USTB.csv
# archive/etfs\USVM.csv
# archive/etfs\UTES.csv
# archive/etfs\UTRN.csv
# archive/etfs\UTSL.csv
# archive/etfs\UUP.csv
# archive/etfs\UVXY.csv
# archive/etfs\UWM.csv
# archive/etfs\UWT.csv
# archive/etfs\UXI.csv
# archive/etfs\UYG.csv
# archive/etfs\UYM.csv
# archive/etfs\VALQ.csv
# archive/etfs\VALT.csv
# archive/etfs\VALX.csv
# archive/etfs\VAMO.csv
# archive/etfs\VAW.csv
# archive/etfs\VB.csv
# archive/etfs\VBK.csv
# archive/etfs\VBND.csv
# archive/etfs\VBR.csv
# archive/etfs\VCIT.csv
# archive/etfs\VCLT.csv
# archive/etfs\VCR.csv
# archive/etfs\VCSH.csv
# archive/etfs\VDC.csv
# archive/etfs\VDE.csv
# archive/etfs\VEA.csv
# archive/etfs\VEGA.csv
# archive/etfs\VEGI.csv
# archive/etfs\VEGN.csv
# archive/etfs\VETS.csv
# archive/etfs\VEU.csv
# archive/etfs\VFH.csv
# archive/etfs\VFLQ.csv
# archive/etfs\VFMF.csv
# archive/etfs\VFMO.csv
# archive/etfs\VFMV.csv
# archive/etfs\VFQY.csv
# archive/etfs\VFVA.csv
# archive/etfs\VGFO.csv
# archive/etfs\VGIT.csv
# archive/etfs\VGK.csv
# archive/etfs\VGLT.csv
# archive/etfs\VGSH.csv
# archive/etfs\VGT.csv
# archive/etfs\VHT.csv
# archive/etfs\VIDI.csv
# archive/etfs\VIG.csv
# archive/etfs\VIGI.csv
# archive/etfs\VIOG.csv
# archive/etfs\VIOO.csv
# archive/etfs\VIOV.csv
# archive/etfs\VIS.csv
# archive/etfs\VIXM.csv
# archive/etfs\VIXY.csv
# archive/etfs\VLU.csv
# archive/etfs\VLUE.csv
# archive/etfs\VMBS.csv
# archive/etfs\VMOT.csv
# archive/etfs\VNLA.csv
# archive/etfs\VNM.csv
# archive/etfs\VNQ.csv
# archive/etfs\VNQI.csv
# archive/etfs\VO.csv
# archive/etfs\VOE.csv
# archive/etfs\VONE.csv
# archive/etfs\VONG.csv
# archive/etfs\VONV.csv
# archive/etfs\VOO.csv
# archive/etfs\VOOG.csv
# archive/etfs\VOOV.csv
# archive/etfs\VOT.csv
# archive/etfs\VOX.csv
# archive/etfs\VPC.csv
# archive/etfs\VPL.csv
# archive/etfs\VPU.csv
# archive/etfs\VRAI.csv
# archive/etfs\VRIG.csv
# archive/etfs\VRP.csv
# archive/etfs\VSDA.csv
# archive/etfs\VSGX.csv
# archive/etfs\VSL.csv
# archive/etfs\VSMV.csv
# archive/etfs\VSS.csv
# archive/etfs\VT.csv
# archive/etfs\VTC.csv
# archive/etfs\VTEB.csv
# archive/etfs\VTHR.csv
# archive/etfs\VTI.csv
# archive/etfs\VTIP.csv
# archive/etfs\VTV.csv
# archive/etfs\VTWG.csv
# archive/etfs\VTWO.csv
# archive/etfs\VTWV.csv
# archive/etfs\VUG.csv
# archive/etfs\VUSE.csv
# archive/etfs\VV.csv
# archive/etfs\VWO.csv
# archive/etfs\VWOB.csv
# archive/etfs\VXF.csv
# archive/etfs\VXUS.csv
# archive/etfs\VYM.csv
# archive/etfs\VYMI.csv
# archive/etfs\WANT.csv
# archive/etfs\WBIE.csv
# archive/etfs\WBIF.csv
# archive/etfs\WBIG.csv
# archive/etfs\WBII.csv
# archive/etfs\WBIL.csv
# archive/etfs\WBIN.csv
# archive/etfs\WBIT.csv
# archive/etfs\WBIY.csv
# archive/etfs\WBND.csv
# archive/etfs\WCHN.csv
# archive/etfs\WCLD.csv
# archive/etfs\WDIV.csv
# archive/etfs\WEAT.csv
# archive/etfs\WEBL.csv
# archive/etfs\WEBS.csv
# archive/etfs\WFHY.csv
# archive/etfs\WFIG.csv
# archive/etfs\WINC.csv
# archive/etfs\WIP.csv
# archive/etfs\WIZ.csv
# archive/etfs\WLDR.csv
# archive/etfs\WOMN.csv
# archive/etfs\WOOD.csv
# archive/etfs\WPS.csv
# archive/etfs\WTMF.csv
# archive/etfs\WWJD.csv
# archive/etfs\XAR.csv
# archive/etfs\XBI.csv
# archive/etfs\XBUY.csv
# archive/etfs\XCEM.csv
# archive/etfs\XCOM.csv
# archive/etfs\XDIV.csv
# archive/etfs\XES.csv
# archive/etfs\XHB.csv
# archive/etfs\XHE.csv
# archive/etfs\XHS.csv
# archive/etfs\XITK.csv
# archive/etfs\XLB.csv
# archive/etfs\XLC.csv
# archive/etfs\XLE.csv
# archive/etfs\XLF.csv
# archive/etfs\XLG.csv
# archive/etfs\XLI.csv
# archive/etfs\XLK.csv
# archive/etfs\XLP.csv
# archive/etfs\XLRE.csv
# archive/etfs\XLSR.csv
# archive/etfs\XLU.csv
# archive/etfs\XLV.csv
# archive/etfs\XLY.csv
# archive/etfs\XME.csv
# archive/etfs\XMHQ.csv
# archive/etfs\XMLV.csv
# archive/etfs\XMMO.csv
# archive/etfs\XMPT.csv
# archive/etfs\XMVM.csv
# archive/etfs\XNTK.csv
# archive/etfs\XOP.csv
# archive/etfs\XOUT.csv
# archive/etfs\XPH.csv
# archive/etfs\XPP.csv
# archive/etfs\XRLV.csv
# archive/etfs\XRT.csv
# archive/etfs\XSD.csv
# archive/etfs\XSHD.csv
# archive/etfs\XSHQ.csv
# archive/etfs\XSLV.csv
# archive/etfs\XSMO.csv
# archive/etfs\XSOE.csv
# archive/etfs\XSVM.csv
# archive/etfs\XSW.csv
# archive/etfs\XT.csv
# archive/etfs\XTH.csv
# archive/etfs\XTL.csv
# archive/etfs\XTN.csv
# archive/etfs\XWEB.csv
# archive/etfs\YANG.csv
# archive/etfs\YCL.csv
# archive/etfs\YCOM.csv
# archive/etfs\YCS.csv
# archive/etfs\YINN.csv
# archive/etfs\YLCO.csv
# archive/etfs\YLD.csv
# archive/etfs\YLDE.csv
# archive/etfs\YOLO.csv
# archive/etfs\YXI.csv
# archive/etfs\YYY.csv
# archive/etfs\ZCAN.csv
# archive/etfs\ZDEU.csv
# archive/etfs\ZGBR.csv
# archive/etfs\ZHOK.csv
# archive/etfs\ZIG.csv
# archive/etfs\ZJPN.csv
# archive/etfs\ZMLP.csv
# archive/etfs\ZROZ.csv
# archive/etfs\ZSL.csv
# archive/stocks\A.csv
# archive/stocks\AA.csv
# archive/stocks\AACG.csv
# archive/stocks\AAL.csv
# archive/stocks\AAMC.csv
# archive/stocks\AAME.csv
# archive/stocks\AAN.csv
# archive/stocks\AAOI.csv
# archive/stocks\AAON.csv
# archive/stocks\AAP.csv
# archive/stocks\AAPL.csv
# archive/stocks\AAT.csv
# archive/stocks\AAU.csv
# archive/stocks\AAWW.csv
# archive/stocks\AAXN.csv
# archive/stocks\AB.csv
# archive/stocks\ABB.csv
# archive/stocks\ABBV.csv
# archive/stocks\ABC.csv
# archive/stocks\ABCB.csv
# archive/stocks\ABEO.csv
# archive/stocks\ABEV.csv
# archive/stocks\ABG.csv
# archive/stocks\ABIO.csv
# archive/stocks\ABM.csv
# archive/stocks\ABMD.csv
# archive/stocks\ABR.csv
# archive/stocks\ABT.csv
# archive/stocks\ABTX.csv
# archive/stocks\ABUS.csv
# archive/stocks\AC.csv
# archive/stocks\ACA.csv
# archive/stocks\ACAD.csv
# archive/stocks\ACAM.csv
# archive/stocks\ACAMU.csv
# archive/stocks\ACB.csv
# archive/stocks\ACBI.csv
# archive/stocks\ACC.csv
# archive/stocks\ACCO.csv
# archive/stocks\ACEL.csv
# archive/stocks\ACER.csv
# archive/stocks\ACGL.csv
# archive/stocks\ACGLO.csv
# ...
# archive/stocks\TIGR.csv
# archive/stocks\TILE.csv
# archive/stocks\TIPT.csv
# archive/stocks\TISI.csv
# archive/stocks\TITN.csv
# archive/stocks\TIVO.csv
# archive/stocks\TJX.csv
# archive/stocks\TK.csv
# archive/stocks\TKAT.csv
# archive/stocks\TKC.csv
# archive/stocks\TKR.csv
# archive/stocks\TLC.csv
# archive/stocks\TLF.csv
# archive/stocks\TLGT.csv
# archive/stocks\TLI.csv
# archive/stocks\TLK.csv
# archive/stocks\TLND.csv
# archive/stocks\TLRD.csv
# archive/stocks\TLRY.csv
# archive/stocks\TLSA.csv
# archive/stocks\TLYS.csv
# archive/stocks\TM.csv
# archive/stocks\TMDI.csv
# archive/stocks\TMDX.csv
# archive/stocks\TME.csv
# archive/stocks\TMHC.csv
# archive/stocks\TMO.csv
# archive/stocks\TMP.csv
# archive/stocks\TMQ.csv
# archive/stocks\TMSR.csv
# archive/stocks\TMST.csv
# archive/stocks\TMUS.csv
# archive/stocks\TNAV.csv
# archive/stocks\TNC.csv
# archive/stocks\TNDM.csv
# archive/stocks\TNET.csv
# archive/stocks\TNK.csv
# archive/stocks\TNP.csv
# archive/stocks\TNXP.csv
# archive/stocks\TOCA.csv
# archive/stocks\TOL.csv
# archive/stocks\TOPS.csv
# archive/stocks\TORC.csv
# archive/stocks\TOT.csv
# archive/stocks\TOTA.csv
# archive/stocks\TOTAU.csv
# archive/stocks\TOUR.csv
# archive/stocks\TOWN.csv
# archive/stocks\TPB.csv
# archive/stocks\TPC.csv
# archive/stocks\TPCO.csv
# archive/stocks\TPH.csv
# archive/stocks\TPHS.csv
# archive/stocks\TPIC.csv
# archive/stocks\TPL.csv
# archive/stocks\TPR.csv
# archive/stocks\TPRE.csv
# archive/stocks\TPTX.csv
# archive/stocks\TPVG.csv
# archive/stocks\TPVY.csv
# archive/stocks\TPX.csv
# archive/stocks\TPZ.csv
# archive/stocks\TR.csv
# archive/stocks\TRC.csv
# archive/stocks\TRCH.csv
# archive/stocks\TREC.csv
# archive/stocks\TREE.csv
# archive/stocks\TREX.csv
# archive/stocks\TRGP.csv
# archive/stocks\TRHC.csv
# archive/stocks\TRI.csv
# archive/stocks\TRIB.csv
# archive/stocks\TRIL.csv
# archive/stocks\TRIP.csv
# archive/stocks\TRMB.csv
# archive/stocks\TRMD.csv
# archive/stocks\TRMK.csv
# archive/stocks\TRMT.csv
# archive/stocks\TRN.csv
# archive/stocks\TRNE.csv
# archive/stocks\TRNO.csv
# archive/stocks\TRNS.csv
# archive/stocks\TRNX.csv
# archive/stocks\TROV.csv
# archive/stocks\TROW.csv
# archive/stocks\TROX.csv
# archive/stocks\TRP.csv
# archive/stocks\TRPX.csv
# archive/stocks\TRQ.csv
# archive/stocks\TRS.csv
# archive/stocks\TRST.csv
# archive/stocks\TRT.csv
# archive/stocks\TRTN.csv
# archive/stocks\TRTX.csv
# archive/stocks\TRU.csv
# archive/stocks\TRUE.csv
# archive/stocks\TRUP.csv
# archive/stocks\TRV.csv
# archive/stocks\TRVG.csv
# archive/stocks\TRVI.csv
# archive/stocks\TRVN.csv
# archive/stocks\TRWH.csv
# archive/stocks\TRX.csv
# archive/stocks\TRXC.csv
# archive/stocks\TS.csv
# archive/stocks\TSBK.csv
# archive/stocks\TSC.csv
# archive/stocks\TSCAP.csv
# archive/stocks\TSCBP.csv
# archive/stocks\TSCO.csv
# archive/stocks\TSE.csv
# archive/stocks\TSEM.csv
# archive/stocks\TSG.csv
# archive/stocks\TSI.csv
# archive/stocks\TSLA.csv
# archive/stocks\TSLF.csv
# archive/stocks\TSLX.csv
# archive/stocks\TSM.csv
# archive/stocks\TSN.csv
# archive/stocks\TSQ.csv
# archive/stocks\TSRI.csv
# archive/stocks\TSU.csv
# archive/stocks\TT.csv
# archive/stocks\TTC.csv
# archive/stocks\TTD.csv
# archive/stocks\TTEC.csv
# archive/stocks\TTEK.csv
# archive/stocks\TTGT.csv
# archive/stocks\TTI.csv
# archive/stocks\TTM.csv
# archive/stocks\TTMI.csv
# archive/stocks\TTNP.csv
# archive/stocks\TTOO.csv
# archive/stocks\TTP.csv
# archive/stocks\TTPH.csv
# archive/stocks\TTWO.csv
# archive/stocks\TU.csv
# archive/stocks\TUES.csv
# archive/stocks\TUFN.csv
# archive/stocks\TUP.csv
# archive/stocks\TURN.csv
# archive/stocks\TUSK.csv
# archive/stocks\TV.csv
# archive/stocks\TVC.csv
# archive/stocks\TVE.csv
# archive/stocks\TVIX.csv
# archive/stocks\TVTY.csv
# archive/stocks\TW.csv
# archive/stocks\TWI.csv
# archive/stocks\TWIN.csv
# archive/stocks\TWLO.csv
# archive/stocks\TWMC.csv
# archive/stocks\TWN.csv
# archive/stocks\TWNK.csv
# archive/stocks\TWNKW.csv
# archive/stocks\TWO.csv
# archive/stocks\TWOU.csv
# archive/stocks\TWST.csv
# archive/stocks\TWTR.csv
# archive/stocks\TX.csv
# archive/stocks\TXG.csv
# archive/stocks\TXMD.csv
# archive/stocks\TXN.csv
# archive/stocks\TXRH.csv
# archive/stocks\TXT.csv
# archive/stocks\TY.csv
# archive/stocks\TYG.csv
# archive/stocks\TYHT.csv
# archive/stocks\TYL.csv
# archive/stocks\TYME.csv
# archive/stocks\TZAC.csv
# archive/stocks\TZACU.csv
# archive/stocks\TZOO.csv
# archive/stocks\UA.csv
# archive/stocks\UAA.csv
# archive/stocks\UAG.csv
# archive/stocks\UAL.csv
# archive/stocks\UAMY.csv
# archive/stocks\UAN.csv
# archive/stocks\UAUD.csv
# archive/stocks\UAVS.csv
# archive/stocks\UBA.csv
# archive/stocks\UBCP.csv
# archive/stocks\UBER.csv
# archive/stocks\UBFO.csv
# archive/stocks\UBG.csv
# archive/stocks\UBOH.csv
# archive/stocks\UBP.csv
# archive/stocks\UBS.csv
# archive/stocks\UBSI.csv
# archive/stocks\UBX.csv
# archive/stocks\UCBI.csv
# archive/stocks\UCHF.csv
# archive/stocks\UCI.csv
# archive/stocks\UCIB.csv
# archive/stocks\UCTT.csv
# archive/stocks\UDR.csv
# archive/stocks\UE.csv
# archive/stocks\UEC.csv
# archive/stocks\UEIC.csv
# archive/stocks\UEPS.csv
# archive/stocks\UEUR.csv
# archive/stocks\UFAB.csv
# archive/stocks\UFCS.csv
# archive/stocks\UFI.csv
# archive/stocks\UFPI.csv
# archive/stocks\UFPT.csv
# archive/stocks\UFS.csv
# archive/stocks\UG.csv
# archive/stocks\UGAZ.csv
# archive/stocks\UGBP.csv
# archive/stocks\UGI.csv
# archive/stocks\UGLD.csv
# archive/stocks\UGP.csv
# archive/stocks\UHAL.csv
# archive/stocks\UHS.csv
# archive/stocks\UHT.csv
# archive/stocks\UI.csv
# archive/stocks\UIHC.csv
# archive/stocks\UIS.csv
# archive/stocks\UJPY.csv
# archive/stocks\UL.csv
# archive/stocks\ULBI.csv
# archive/stocks\ULH.csv
# archive/stocks\ULTA.csv
# archive/stocks\UMBF.csv
# archive/stocks\UMC.csv
# archive/stocks\UMH.csv
# archive/stocks\UMPQ.csv
# archive/stocks\UMRX.csv
# archive/stocks\UN.csv
# archive/stocks\UNAM.csv
# archive/stocks\UNB.csv
# archive/stocks\UNF.csv
# archive/stocks\UNFI.csv
# archive/stocks\UNH.csv
# archive/stocks\UNIT.csv
# archive/stocks\UNM.csv
# archive/stocks\UNMA.csv
# archive/stocks\UNP.csv
# archive/stocks\UNT.csv
# archive/stocks\UNTY.csv
# archive/stocks\UNVR.csv
# archive/stocks\UONE.csv
# archive/stocks\UONEK.csv
# archive/stocks\UPLD.csv
# archive/stocks\UPS.csv
# archive/stocks\UPWK.csv
# archive/stocks\URBN.csv
# archive/stocks\URG.csv
# archive/stocks\URGN.csv
# archive/stocks\URI.csv
# archive/stocks\UROV.csv
# archive/stocks\URR.csv
# archive/stocks\USA.csv
# archive/stocks\USAC.csv
# archive/stocks\USAK.csv
# archive/stocks\USAP.csv
# archive/stocks\USAS.csv
# archive/stocks\USAU.csv
# archive/stocks\USB.csv
# archive/stocks\USCR.csv
# archive/stocks\USDP.csv
# archive/stocks\USEG.csv
# archive/stocks\USFD.csv
# archive/stocks\USIO.csv
# archive/stocks\USLM.csv
# archive/stocks\USLV.csv
# archive/stocks\USM.csv
# archive/stocks\USNA.csv
# archive/stocks\USOI.csv
# archive/stocks\USPH.csv
# archive/stocks\USV.csv
# archive/stocks\USWS.csv
# archive/stocks\USX.csv
# archive/stocks\UTF.csv
# archive/stocks\UTG.csv
# archive/stocks\UTHR.csv
# archive/stocks\UTI.csv
# archive/stocks\UTL.csv
# archive/stocks\UTMD.csv
# archive/stocks\UTSI.csv
# archive/stocks\UTX#.csv
# archive/stocks\UTX.csv
# archive/stocks\UUU.csv
# archive/stocks\UUUU.csv
# archive/stocks\UVE.csv
# archive/stocks\UVSP.csv
# archive/stocks\UVV.csv
# archive/stocks\UXIN.csv
# archive/stocks\UZA.csv
# archive/stocks\UZB.csv
# archive/stocks\UZC.csv
# archive/stocks\V.csv
# archive/stocks\VAC.csv
# archive/stocks\VAL.csv
# archive/stocks\VALE.csv
# archive/stocks\VALU.csv
# archive/stocks\VAM.csv
# archive/stocks\VAPO.csv
# archive/stocks\VAR.csv
# archive/stocks\VBF.csv
# archive/stocks\VBFC.csv
# archive/stocks\VBIV.csv
# archive/stocks\VBLT.csv
# archive/stocks\VBTX.csv
# archive/stocks\VC.csv
# archive/stocks\VCEL.csv
# archive/stocks\VCF.csv
# archive/stocks\VCIF.csv
# archive/stocks\VCNX.csv
# archive/stocks\VCRA.csv
# archive/stocks\VCTR.csv
# archive/stocks\VCV.csv
# archive/stocks\VCYT.csv
# archive/stocks\VEC.csv
# archive/stocks\VECO.csv
# archive/stocks\VEDL.csv
# archive/stocks\VEEV.csv
# archive/stocks\VEL.csv
# archive/stocks\VEON.csv
# archive/stocks\VER.csv
# archive/stocks\VERB.csv
# archive/stocks\VERI.csv
# archive/stocks\VERO.csv
# archive/stocks\VERU.csv
# archive/stocks\VERY.csv
# archive/stocks\VET.csv
# archive/stocks\VFC.csv
# archive/stocks\VFF.csv
# archive/stocks\VFL.csv
# archive/stocks\VG.csv
# archive/stocks\VGI.csv
# archive/stocks\VGM.csv
# archive/stocks\VGR.csv
# archive/stocks\VGZ.csv
# archive/stocks\VHC.csv
# archive/stocks\VHI.csv
# archive/stocks\VIAC.csv
# archive/stocks\VIACA.csv
# archive/stocks\VIAV.csv
# archive/stocks\VICI.csv
# archive/stocks\VICR.csv
# archive/stocks\VIE.csv
# archive/stocks\VIIX.csv
# archive/stocks\VIOT.csv
# archive/stocks\VIPS.csv
# archive/stocks\VIR.csv
# archive/stocks\VIRC.csv
# archive/stocks\VIRT.csv
# archive/stocks\VISL.csv
# archive/stocks\VIST.csv
# archive/stocks\VIV.csv
# archive/stocks\VIVE.csv
# archive/stocks\VIVO.csv
# archive/stocks\VJET.csv
# archive/stocks\VKI.csv
# archive/stocks\VKQ.csv
# archive/stocks\VKTX.csv
# archive/stocks\VLGEA.csv
# archive/stocks\VLO.csv
# archive/stocks\VLRS.csv
# archive/stocks\VLT.csv
# archive/stocks\VLY.csv
# archive/stocks\VLYPO.csv
# archive/stocks\VLYPP.csv
# archive/stocks\VMC.csv
# archive/stocks\VMD.csv
# archive/stocks\VMI.csv
# archive/stocks\VMM.csv
# archive/stocks\VMO.csv
# archive/stocks\VMW.csv
# archive/stocks\VNCE.csv
# archive/stocks\VNDA.csv
# archive/stocks\VNE.csv
# archive/stocks\VNET.csv
# archive/stocks\VNO.csv
# archive/stocks\VNOM.csv
# archive/stocks\VNRX.csv
# archive/stocks\VNTR.csv
# archive/stocks\VOC.csv
# archive/stocks\VOD.csv
# archive/stocks\VOLT.csv
# archive/stocks\VOXX.csv
# archive/stocks\VOYA.csv
# archive/stocks\VPG.csv
# archive/stocks\VPV.csv
# archive/stocks\VQT.csv
# archive/stocks\VRA.csv
# archive/stocks\VRAY.csv
# archive/stocks\VRCA.csv
# archive/stocks\VREX.csv
# archive/stocks\VRML.csv
# archive/stocks\VRNA.csv
# archive/stocks\VRNS.csv
# archive/stocks\VRNT.csv
# archive/stocks\VRRM.csv
# archive/stocks\VRS.csv
# archive/stocks\VRSK.csv
# archive/stocks\VRSN.csv
# archive/stocks\VRT.csv
# archive/stocks\VRTS.csv
# archive/stocks\VRTU.csv
# archive/stocks\VRTV.csv
# archive/stocks\VRTX.csv
# archive/stocks\VSAT.csv
# archive/stocks\VSEC.csv
# archive/stocks\VSH.csv
# archive/stocks\VSLR.csv
# archive/stocks\VST.csv
# archive/stocks\VSTM.csv
# archive/stocks\VSTO.csv
# archive/stocks\VTA.csv
# archive/stocks\VTGN.csv
# archive/stocks\VTIQ.csv
# archive/stocks\VTIQU.csv
# archive/stocks\VTIQW.csv
# archive/stocks\VTN.csv
# archive/stocks\VTNR.csv
# archive/stocks\VTR.csv
# archive/stocks\VTSI.csv
# archive/stocks\VTVT.csv
# archive/stocks\VUZI.csv
# archive/stocks\VVI.csv
# archive/stocks\VVNT.csv
# archive/stocks\VVPR.csv
# archive/stocks\VVR.csv
# archive/stocks\VVUS.csv
# archive/stocks\VVV.csv
# archive/stocks\VXRT.csv
# archive/stocks\VXX.csv
# archive/stocks\VXZ.csv
# archive/stocks\VYGR.csv
# archive/stocks\VZ.csv
# archive/stocks\W.csv
# archive/stocks\WAB.csv
# archive/stocks\WABC.csv
# archive/stocks\WAFD.csv
# archive/stocks\WAFU.csv
# archive/stocks\WAL.csv
# archive/stocks\WALA.csv
# archive/stocks\WASH.csv
# archive/stocks\WAT.csv
# archive/stocks\WATT.csv
# archive/stocks\WB.csv
# archive/stocks\WBA.csv
# archive/stocks\WBAI.csv
# archive/stocks\WBC.csv
# archive/stocks\WBK.csv
# archive/stocks\WBS.csv
# archive/stocks\WBT.csv
# archive/stocks\WCC.csv
# archive/stocks\WCN.csv
# archive/stocks\WD.csv
# archive/stocks\WDAY.csv
# archive/stocks\WDC.csv
# archive/stocks\WDFC.csv
# archive/stocks\WDR.csv
# archive/stocks\WEA.csv
# archive/stocks\WEBK.csv
# archive/stocks\WEC.csv
# archive/stocks\WEI.csv
# archive/stocks\WELL.csv
# archive/stocks\WEN.csv
# archive/stocks\WERN.csv
# archive/stocks\WES.csv
# archive/stocks\WETF.csv
# archive/stocks\WEX.csv
# archive/stocks\WEYS.csv
# archive/stocks\WF.csv
# archive/stocks\WFC.csv
# archive/stocks\WGO.csv
# archive/stocks\WH.csv
# archive/stocks\WHD.csv
# archive/stocks\WHF.csv
# archive/stocks\WHFBZ.csv
# archive/stocks\WHG.csv
# archive/stocks\WHLM.csv
# archive/stocks\WHLR.csv
# archive/stocks\WHLRD.csv
# archive/stocks\WHLRP.csv
# archive/stocks\WHR.csv
# archive/stocks\WIA.csv
# archive/stocks\WIFI.csv
# archive/stocks\WIL.csv
# archive/stocks\WILC.csv
# archive/stocks\WINA.csv
# archive/stocks\WING.csv
# archive/stocks\WINS.csv
# archive/stocks\WIRE.csv
# archive/stocks\WISA.csv
# archive/stocks\WIT.csv
# archive/stocks\WIW.csv
# archive/stocks\WIX.csv
# archive/stocks\WK.csv
# archive/stocks\WKEY.csv
# archive/stocks\WKHS.csv
# archive/stocks\WLDN.csv
# archive/stocks\WLFC.csv
# archive/stocks\WLK.csv
# archive/stocks\WLKP.csv
# archive/stocks\WLL.csv
# archive/stocks\WLTW.csv
# archive/stocks\WM.csv
# archive/stocks\WMB.csv
# archive/stocks\WMC.csv
# archive/stocks\WMGI.csv
# archive/stocks\WMK.csv
# archive/stocks\WMS.csv
# archive/stocks\WMT.csv
# archive/stocks\WNC.csv
# archive/stocks\WNEB.csv
# archive/stocks\WNS.csv
# archive/stocks\WOR.csv
# archive/stocks\WORK.csv
# archive/stocks\WORX.csv
# archive/stocks\WOW.csv
# archive/stocks\WPC.csv
# archive/stocks\WPG.csv
# archive/stocks\WPM.csv
# archive/stocks\WPP.csv
# archive/stocks\WPRT.csv
# archive/stocks\WPX.csv
# archive/stocks\WRB.csv
# archive/stocks\WRE.csv
# archive/stocks\WRI.csv
# archive/stocks\WRK.csv
# archive/stocks\WRLD.csv
# archive/stocks\WRLS.csv
# archive/stocks\WRLSU.csv
# archive/stocks\WRN.csv
# archive/stocks\WRTC.csv
# archive/stocks\WSBC.csv
# archive/stocks\WSBF.csv
# archive/stocks\WSC.csv
# archive/stocks\WSFS.csv
# archive/stocks\WSG.csv
# archive/stocks\WSM.csv
# archive/stocks\WSO.csv
# archive/stocks\WSR.csv
# archive/stocks\WST.csv
# archive/stocks\WSTG.csv
# archive/stocks\WSTL.csv
# archive/stocks\WTBA.csv
# archive/stocks\WTER.csv
# archive/stocks\WTFC.csv
# archive/stocks\WTFCM.csv
# archive/stocks\WTI.csv
# archive/stocks\WTIU.csv
# archive/stocks\WTM.csv
# archive/stocks\WTRE.csv
# archive/stocks\WTREP.csv
# archive/stocks\WTRG.csv
# archive/stocks\WTRH.csv
# archive/stocks\WTRU.csv
# archive/stocks\WTS.csv
# archive/stocks\WTT.csv
# archive/stocks\WTTR.csv
# archive/stocks\WU.csv
# archive/stocks\WUBA.csv
# archive/stocks\WVE.csv
# archive/stocks\WVFC.csv
# archive/stocks\WVVI.csv
# archive/stocks\WVVIP.csv
# archive/stocks\WW.csv
# archive/stocks\WWD.csv
# archive/stocks\WWE.csv
# archive/stocks\WWR.csv
# archive/stocks\WWW.csv
# archive/stocks\WY.csv
# archive/stocks\WYND.csv
# archive/stocks\WYNN.csv
# archive/stocks\WYY.csv
# archive/stocks\X.csv
# archive/stocks\XAIR.csv
# archive/stocks\XAN.csv
# archive/stocks\XBIO.csv
# archive/stocks\XBIOW.csv
# archive/stocks\XBIT.csv
# archive/stocks\XCUR.csv
# archive/stocks\XEC.csv
# archive/stocks\XEL.csv
# archive/stocks\XELA.csv
# archive/stocks\XELB.csv
# archive/stocks\XENE.csv
# archive/stocks\XENT.csv
# archive/stocks\XERS.csv
# archive/stocks\XFLT.csv
# archive/stocks\XFOR.csv
# archive/stocks\XGN.csv
# archive/stocks\XHR.csv
# archive/stocks\XIN.csv
# archive/stocks\XLNX.csv
# archive/stocks\XLRN.csv
# archive/stocks\XNCR.csv
# archive/stocks\XNET.csv
# archive/stocks\XOG.csv
# archive/stocks\XOM.csv
# archive/stocks\XOMA.csv
# archive/stocks\XONE.csv
# archive/stocks\XP.csv
# archive/stocks\XPEL.csv
# archive/stocks\XPER.csv
# archive/stocks\XPL.csv
# archive/stocks\XPO.csv
# archive/stocks\XRAY.csv
# archive/stocks\XRF.csv
# archive/stocks\XRX.csv
# archive/stocks\XSPA.csv
# archive/stocks\XTLB.csv
# archive/stocks\XTNT.csv
# archive/stocks\XVZ.csv
# archive/stocks\XXII.csv
# archive/stocks\XYF.csv
# archive/stocks\XYL.csv
# archive/stocks\Y.csv
# archive/stocks\YCBD.csv
# archive/stocks\YELP.csv
# archive/stocks\YETI.csv
# archive/stocks\YEXT.csv
# archive/stocks\YGRN.csv
# archive/stocks\YGYI.csv
# archive/stocks\YGYIP.csv
# archive/stocks\YI.csv
# archive/stocks\YIN.csv
# archive/stocks\YJ.csv
# archive/stocks\YMAB.csv
# archive/stocks\YNDX.csv
# archive/stocks\YORW.csv
# archive/stocks\YPF.csv
# archive/stocks\YRCW.csv
# archive/stocks\YRD.csv
# archive/stocks\YTEN.csv
# archive/stocks\YTRA.csv
# archive/stocks\YUM.csv
# archive/stocks\YUMA.csv
# archive/stocks\YUMC.csv
# archive/stocks\YVR.csv
# archive/stocks\YY.csv
# archive/stocks\Z.csv
# archive/stocks\ZAGG.csv
# archive/stocks\ZBH.csv
# archive/stocks\ZBRA.csv
# archive/stocks\ZCMD.csv
# archive/stocks\ZDGE.csv
# archive/stocks\ZEAL.csv
# archive/stocks\ZEN.csv
# archive/stocks\ZEUS.csv
# archive/stocks\ZFGN.csv
# archive/stocks\ZG.csv
# archive/stocks\ZGNX.csv
# archive/stocks\ZGYHU.csv
# archive/stocks\ZION.csv
# archive/stocks\ZIONL.csv
# archive/stocks\ZIONN.csv
# archive/stocks\ZIONO.csv
# archive/stocks\ZIONP.csv
# archive/stocks\ZIONW.csv
# archive/stocks\ZIOP.csv
# archive/stocks\ZIV.csv
# archive/stocks\ZIXI.csv
# archive/stocks\ZKIN.csv
# archive/stocks\ZLAB.csv
# archive/stocks\ZM.csv
# archive/stocks\ZN.csv
# archive/stocks\ZNGA.csv
# archive/stocks\ZNH.csv
# archive/stocks\ZOM.csv
# archive/stocks\ZS.csv
# archive/stocks\ZSAN.csv
# archive/stocks\ZTO.csv
# archive/stocks\ZTR.csv
# archive/stocks\ZTS.csv
# archive/stocks\ZUMZ.csv
# archive/stocks\ZUO.csv
# archive/stocks\ZVO.csv
# archive/stocks\ZYME.csv
# archive/stocks\ZYNE.csv
# archive/stocks\ZYXI.csv

# %%
data = pd.read_csv('archive/stocks/AAPL.csv')
data.head(10)
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.406782  117258400
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.385558   43971200
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.357260   26432000
# 3  1980-12-17  0.462054  0.464286  0.462054  0.462054   0.366103   21610400
# 4  1980-12-18  0.475446  0.477679  0.475446  0.475446   0.376715   18362400
# 5  1980-12-19  0.504464  0.506696  0.504464  0.504464   0.399707   12157600
# 6  1980-12-22  0.529018  0.531250  0.529018  0.529018   0.419162    9340800
# 7  1980-12-23  0.551339  0.553571  0.551339  0.551339   0.436848   11737600
# 8  1980-12-24  0.580357  0.582589  0.580357  0.580357   0.459840   12000800
# 9  1980-12-26  0.633929  0.636161  0.633929  0.633929   0.502287   13893600

# %%
data.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
data2=data.fillna(0)

# %%
data2=data2.loc[:, data2.columns!='Date']

# %%
data2.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %% [markdown]
# # Pre-Processing

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0,1))
data_scaled = sc.fit_transform(data2)

# %%
sns.set(rc = {'figure.figsize':(15,8)})

# %%
data2.tail()
# Out:
#             Open        High         Low       Close   Adj Close    Volume
# 9904  246.520004  258.679993  246.360001  258.440002  258.440002  63021800
# 9905  252.750000  255.869995  247.050003  247.740005  247.740005  51054200
# 9906  250.740005  255.520004  249.399994  254.809998  254.809998  41994100
# 9907  255.600006  262.489990  252.000000  254.289993  254.289993  49250500
# 9908  246.500000  248.720001  239.130005  240.910004  240.910004  43956200

# %%
data2.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  9909.000000  9909.000000  9909.000000  9909.000000  9909.000000
# mean     32.606849    32.936079    32.277560    32.618030    30.576570
# std      58.415759    59.001576    57.883037    58.471899    56.746275
# min       0.198661     0.198661     0.196429     0.196429     0.155638
# 25%       1.071429     1.089286     1.048571     1.071429     0.917643
# 50%       1.729286     1.758929     1.696429     1.732143     1.466154
# 75%      35.799999    36.265713    35.328571    35.761429    31.042374
# max     324.739990   327.850006   323.350006   327.200012   327.200012
#
#              Volume
# count  9.909000e+03
# mean   8.582916e+07
# std    8.597195e+07
# min    3.472000e+05
# 25%    3.304230e+07
# 50%    5.766490e+07
# 75%    1.069992e+08
# max    1.855410e+09

# %%
plt.figure(figsize=(15, 5));
plt.subplot(1,2,1);
plt.plot(data2.Open.values, color='red', label='open')
plt.plot(data2.Close.values, color='green', label='close')
plt.plot(data2.Low.values, color='blue', label='low')
plt.plot(data2.High.values, color='black', label='high')
plt.title('Closing Price of AAPL')
plt.xlabel('time [days]')
plt.ylabel('price')
plt.legend(loc='best')
plt.show()

# %%
plt.subplot(1,2,2);
plt.plot(data2.Volume.values, color='black', label='volume')
plt.title('stock volume of AAPL')
plt.xlabel('time [days]')
plt.ylabel('volume')
plt.legend(loc='best');

# %%
data1 = data.sort_index(ascending=True, axis=0)
new_data = pd.DataFrame(index=range(0,len(data)),columns=['Date', 'Close'])
for i in range(0,len(data1)):
    new_data['Date'][i] = data1['Date'][i]
    new_data['Close'][i] = data1['Close'][i]

# %%
new_data['Close']=new_data['Close'].astype(float, errors = 'raise')

# %%
new_data.index = new_data.Date
new_data.drop('Date', axis=1, inplace=True)

# %%
new_data.dtypes
# Out:
# Close    float64
# dtype: object

# %%
dataset = new_data.values

# %%
training_data_len = int(np.ceil( len(dataset) * .95 ))
training_data_len
# Out:
# 9414

# %%
train = dataset[0:987,:]
valid = dataset[987:,:]
valid
# Out:
# array([[  0.45982143],
#        [  0.4419643 ],
#        [  0.41517857],
#        ...,
#        [254.80999756],
#        [254.28999329],
#        [240.91000366]])

# %%
valid=pd.DataFrame(valid)
valid.columns=['Close']
valid
# Out:
#            Close
# 0       0.459821
# 1       0.441964
# 2       0.415179
# 3       0.430804
# 4       0.419643
# ...          ...
# 8917  258.440002
# 8918  247.740005
# 8919  254.809998
# 8920  254.289993
# 8921  240.910004
#
# [8922 rows x 1 columns]

# %%
scalar = MinMaxScaler(feature_range = (0,1))
data_scaled = scalar.fit_transform(dataset)

# %%
X = []
Y = []
size=100
for i in range(1 , len(new_data) - size -1 , 1):
    first = data2.iloc[i,2]
    temp = []
    temp1 = []
    for j in range(size):
        temp.append((data.iloc[i + j, 2] - first) / first)
    temp1.append((data2.iloc[i + size, 2] - first) / first)
    X.append(np.array(temp).reshape(100, 1))
    Y.append(np.array(temp1).reshape(1, 1))

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
X_train1 = np.reshape(X_train, (X_train.shape[0], X_train.shape[1],1))
y_train1 = np.reshape(y_train, (y_train.shape[0],1))

# %%
X_test1 = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))

# %% [markdown]
# # RNN

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import SimpleRNN
from keras.layers import LSTM

# %%
model1 = Sequential()

# %%
model1.add(SimpleRNN(units = 50, activation = "tanh", return_sequences = True, input_shape = (X_train.shape[1],1)))
model1.add(Dropout(0.2))
model1.add(SimpleRNN(units = 50, activation = "tanh", return_sequences = True))
model1.add(Dropout(0.2))
model1.add(SimpleRNN(units = 50, activation = "tanh", return_sequences = True))
model1.add(Dropout(0.2))
model1.add(SimpleRNN(units = 50))
model1.add(Dropout(0.2))
model1.add(Dense(units = 1))

# %%
model1.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics=['accuracy'])

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 100, 50)           2600
#
#  dropout (Dropout)           (None, 100, 50)           0
#
#  simple_rnn_1 (SimpleRNN)    (None, 100, 50)           5050
#
#  dropout_1 (Dropout)         (None, 100, 50)           0
#
#  simple_rnn_2 (SimpleRNN)    (None, 100, 50)           5050
#
#  dropout_2 (Dropout)         (None, 100, 50)           0
#
#  simple_rnn_3 (SimpleRNN)    (None, 50)                5050
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 17,801
# Trainable params: 17,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.fit(X_train1, y_train1, batch_size = 200, epochs = 10, verbose=2)
# Out:
# Epoch 1/10
# 40/40 - 7s - loss: 0.2660 - accuracy: 0.0020 - 7s/epoch - 169ms/step
# Epoch 2/10
# 40/40 - 4s - loss: 0.1126 - accuracy: 0.0025 - 4s/epoch - 92ms/step
# Epoch 3/10
# 40/40 - 4s - loss: 0.0607 - accuracy: 0.0024 - 4s/epoch - 93ms/step
# Epoch 4/10
# 40/40 - 4s - loss: 0.0416 - accuracy: 0.0025 - 4s/epoch - 96ms/step
# Epoch 5/10
# 40/40 - 4s - loss: 0.0294 - accuracy: 0.0025 - 4s/epoch - 91ms/step
# Epoch 6/10
# 40/40 - 4s - loss: 0.0222 - accuracy: 0.0025 - 4s/epoch - 93ms/step
# Epoch 7/10
# 40/40 - 4s - loss: 0.0181 - accuracy: 0.0025 - 4s/epoch - 93ms/step
# Epoch 8/10
# 40/40 - 4s - loss: 0.0155 - accuracy: 0.0025 - 4s/epoch - 96ms/step
# Epoch 9/10
# 40/40 - 4s - loss: 0.0126 - accuracy: 0.0025 - 4s/epoch - 92ms/step
# Epoch 10/10
# 40/40 - 4s - loss: 0.0110 - accuracy: 0.0025 - 4s/epoch - 93ms/step

# %%
inputs = new_data[len(new_data) - len(valid) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = scalar.transform(inputs)

# %%
X_test1 = []
for i in range(100,inputs.shape[0]):
    X_test1.append(inputs[i-100:i,0])
X_test1 = np.array(X_test1)

X_test1 = np.reshape(X_test1, (X_test1.shape[0],X_test1.shape[1],1))
closing_price1 = model1.predict(X_test1)
closing_price1 = scalar.inverse_transform(closing_price1)
# Out:
# 278/278 [==============================] - 3s 10ms/step

# %%
valid1 = new_data[1027:]
rms1=np.sqrt(np.mean(np.power((valid1-closing_price1),2)))
rms1
# Out:
# Close    12.524809
# dtype: float64

# %%
valid1['Predictions'] = closing_price1
# Out:
# C:\Users\DAVIDN~1\AppData\Local\Temp/ipykernel_6476/4114925822.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plt.figure(figsize=(16,8))
plt.title("RNN Model")
plt.xlabel('Days')
plt.ylabel('Close Price USD ($)')
#plt.plot(data2['Close'])
plt.plot(valid1[['Close', 'Predictions']])
plt.legend(["Valid", 'Predicted'])
plt.show()

# %% [markdown]
# # LSTM

# %%
X_train2, y_train2 = np.array(X_train), np.array(y_train)
X_train2 = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))

# %%
model = Sequential()
model.add(LSTM(64,return_sequences=True,input_shape = (X_train2.shape[1],1)))
model.add(LSTM(64, return_sequences= False))
model.add(Dense(32))
model.add(Dense(1))

# %%
model.compile(loss = "mean_squared_error", optimizer = "adam", metrics = ["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 64)           16896
#
#  lstm_1 (LSTM)               (None, 64)                33024
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 52,033
# Trainable params: 52,033
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train2, y_train2, epochs = 10, batch_size = 200, verbose=2)
# Out:
# Epoch 1/10
# 40/40 - 10s - loss: 0.0162 - accuracy: 0.0025 - 10s/epoch - 259ms/step
# Epoch 2/10
# 40/40 - 6s - loss: 0.0045 - accuracy: 0.0025 - 6s/epoch - 159ms/step
# Epoch 3/10
# 40/40 - 7s - loss: 0.0037 - accuracy: 0.0025 - 7s/epoch - 164ms/step
# Epoch 4/10
# 40/40 - 6s - loss: 0.0034 - accuracy: 0.0025 - 6s/epoch - 157ms/step
# Epoch 5/10
# 40/40 - 6s - loss: 0.0031 - accuracy: 0.0025 - 6s/epoch - 161ms/step
# Epoch 6/10
# 40/40 - 7s - loss: 0.0029 - accuracy: 0.0025 - 7s/epoch - 164ms/step
# Epoch 7/10
# 40/40 - 7s - loss: 0.0027 - accuracy: 0.0025 - 7s/epoch - 166ms/step
# Epoch 8/10
# 40/40 - 7s - loss: 0.0025 - accuracy: 0.0025 - 7s/epoch - 183ms/step
# Epoch 9/10
# 40/40 - 7s - loss: 0.0023 - accuracy: 0.0025 - 7s/epoch - 164ms/step
# Epoch 10/10
# 40/40 - 7s - loss: 0.0023 - accuracy: 0.0025 - 7s/epoch - 178ms/step

# %%
X_test2 = []
for i in range(100,inputs.shape[0]):
    X_test2.append(inputs[i-100:i,0])
X_test2 = np.array(X_test2)

X_test2 = np.reshape(X_test2, (X_test2.shape[0],X_test2.shape[1],1))
closing_price1 = model.predict(X_test2)
closing_price1 = scalar.inverse_transform(closing_price1)
# Out:
# 278/278 [==============================] - 5s 16ms/step

# %%
valid = new_data[1027:]
rms=np.sqrt(np.mean(np.power((valid-closing_price1),2)))
rms
# Out:
# Close    12.67212
# dtype: float64

# %%
valid['Predictions'] = closing_price1
# Out:
# C:\Users\DAVIDN~1\AppData\Local\Temp/ipykernel_6476/4044917624.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plt.figure(figsize=(16,8))
plt.title("LSTM Model")
plt.xlabel('Days')
plt.ylabel('Close Price USD ($)')
#plt.plot(data2['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(["Valid", 'Predicted'])
plt.show()

# %% [markdown]
# # Convolution Neural Network

# %%
X_train3 = X_train.reshape(X_train.shape[0],1,100,1)
X_test3 = X_test2.reshape(X_test2.shape[0],1,100,1)

# %%
model = tf.keras.Sequential()

# %%
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Bidirectional, TimeDistributed
from tensorflow.keras.layers import MaxPooling1D, Flatten
from tensorflow.keras.regularizers import L1, L2
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.metrics import RootMeanSquaredError

# %%
# CNN layers
model.add(TimeDistributed(Conv1D(64, kernel_size=2, activation='relu', input_shape=(None, 100, 1))))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Conv1D(128, kernel_size=2, activation='relu')))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Conv1D(64, kernel_size=2, activation='relu')))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Flatten()))
model.add(Dense(5, kernel_regularizer=L2(0.01)))

# LSTM layers
model.add(Bidirectional(LSTM(100, return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(100, return_sequences=False)))
model.add(Dropout(0.5))

#Final layers8
model.add(Dense(1, activation='linear'))

# %%
model.compile(loss='mse',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\DAVIDN~1\AppData\Local\Temp/ipykernel_6476/3470139634.py in <module>
# ----> 1 model.summary()
#
# D:\anaconda3\lib\site-packages\keras\engine\training.py in summary(self, line_length, positions, print_fn, expand_nested, show_trainable)
#    2867     """
#    2868     if not self.built:
# -> 2869       raise ValueError(
#    2870           'This model has not yet been built. '
#    2871           'Build the model first by calling `build()` or by calling '
#
# ValueError: This model has not yet been built. Build the model first by calling `build()` or by calling the model on a batch of data.

# %%
model.fit(X_train3,y_train,batch_size = 200, epochs=10, verbose=2)
# Out:
# Epoch 1/10
# 40/40 - 7s - loss: 0.1187 - accuracy: 0.0025 - 7s/epoch - 164ms/step
# Epoch 2/10
# 40/40 - 1s - loss: 0.0368 - accuracy: 0.0025 - 1s/epoch - 25ms/step
# Epoch 3/10
# 40/40 - 1s - loss: 0.0216 - accuracy: 0.0025 - 1s/epoch - 25ms/step
# Epoch 4/10
# 40/40 - 1s - loss: 0.0164 - accuracy: 0.0025 - 1s/epoch - 25ms/step
# Epoch 5/10
# 40/40 - 1s - loss: 0.0135 - accuracy: 0.0025 - 1s/epoch - 26ms/step
# Epoch 6/10
# 40/40 - 1s - loss: 0.0120 - accuracy: 0.0025 - 1s/epoch - 27ms/step
# Epoch 7/10
# 40/40 - 1s - loss: 0.0120 - accuracy: 0.0025 - 1s/epoch - 25ms/step
# Epoch 8/10
# 40/40 - 1s - loss: 0.0107 - accuracy: 0.0025 - 1s/epoch - 25ms/step
# Epoch 9/10
# 40/40 - 1s - loss: 0.0102 - accuracy: 0.0025 - 1s/epoch - 25ms/step
# Epoch 10/10
# 40/40 - 1s - loss: 0.0103 - accuracy: 0.0025 - 1s/epoch - 25ms/step

# %%
closing_price2 = model.predict(X_test3)
closing_price2 = scalar.inverse_transform(closing_price2)
# Out:
# 278/278 [==============================] - 2s 2ms/step

# %%
rms=np.sqrt(np.mean(np.power((valid-closing_price2),2)))
rms
# Out:
# Close          12.702745
# Predictions    14.490248
# dtype: float64

# %%
valid['Predictions'] = closing_price2
# Out:
# C:\Users\DAVIDN~1\AppData\Local\Temp/ipykernel_6476/4241695185.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plt.figure(figsize=(16,8))
plt.title("Convolution Model")
plt.xlabel('Days')
plt.ylabel('Close Price USD ($)')
#plt.plot(data2['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend([ "Valid", 'Predicted'])
plt.show()

# %% [markdown]
# # Hybrid Algorthim

# %%
X_train4 = np.reshape(new_data.values[:,-1:],newshape=(-1,1,1))
y_train4 = np.reshape(new_data.values[:,-1:],newshape=(-1,1,1))
X_test4 = np.reshape(new_data.values[:8882,:],newshape=(-1,1,1))
X_train4.shape,y_train4.shape,X_test4.shape
# Out:
# ((9909, 1, 1), (9909, 1, 1), (8882, 1, 1))

# %%
X_train4
# Out:
# array([[[  0.51339287]],
#
#        [[  0.48660713]],
#
#        [[  0.45089287]],
#
#        ...,
#
#        [[254.80999756]],
#
#        [[254.28999329]],
#
#        [[240.91000366]]])

# %%
from keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation
from keras.layers import Bidirectional, GlobalMaxPool1D

# %%
model=tf.keras.Sequential()

# %%
model.add(Embedding(25000, 100))
model.add(Bidirectional(LSTM(100, return_sequences=True, dropout=0.25, recurrent_dropout=0.1)))
model.add(GlobalMaxPool1D())
model.add(Dense(100, activation="relu"))
model.add(Dropout(0.25))
model.add(Dense(1, activation="sigmoid"))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 100)         2500000
#
#  bidirectional_6 (Bidirectio  (None, None, 200)        160800
#  nal)
#
#  global_max_pooling1d (Globa  (None, 200)              0
#  lMaxPooling1D)
#
#  dense_9 (Dense)             (None, 100)               20100
#
#  dropout_10 (Dropout)        (None, 100)               0
#
#  dense_10 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 2,681,001
# Trainable params: 2,681,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train4, y_train4, batch_size=100, epochs=10)
# Out:
# Epoch 1/10
# 100/100 [==============================] - 6s 22ms/step - loss: -417.1754 - accuracy: 0.0014
# Epoch 2/10
# 100/100 [==============================] - 2s 20ms/step - loss: -16305.1611 - accuracy: 0.0014
# Epoch 3/10
# 100/100 [==============================] - 2s 18ms/step - loss: -57069.1211 - accuracy: 0.0014
# Epoch 4/10
# 100/100 [==============================] - 2s 20ms/step - loss: -107113.6328 - accuracy: 0.0014
# Epoch 5/10
# 100/100 [==============================] - 2s 19ms/step - loss: -164968.9219 - accuracy: 0.0014
# Epoch 6/10
# 100/100 [==============================] - 2s 19ms/step - loss: -232751.4375 - accuracy: 0.0014
# Epoch 7/10
# 100/100 [==============================] - 2s 18ms/step - loss: -310838.0312 - accuracy: 0.0014
# Epoch 8/10
# 100/100 [==============================] - 2s 18ms/step - loss: -397551.6250 - accuracy: 0.0014
# Epoch 9/10
# 100/100 [==============================] - 2s 19ms/step - loss: -493068.3438 - accuracy: 0.0014
# Epoch 10/10
# 100/100 [==============================] - 2s 19ms/step - loss: -596146.7500 - accuracy: 0.0014

# %%
closing_price4 = model.predict(X_test4)
closing_price4 = scalar.inverse_transform(closing_price4)
# Out:
# 278/278 [==============================] - 1s 1ms/step

# %%
valid = new_data[1027:]
rms=np.sqrt(np.mean(np.power((valid-closing_price4),2)))
rms
# Out:
# Close    266.654363
# dtype: float64

# %%
valid['Predictions'] = closing_price4
# Out:
# C:\Users\DAVIDN~1\AppData\Local\Temp/ipykernel_6476/2437876985.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plt.figure(figsize=(16,8))
plt.title("Hybrid algorithm Model")
plt.xlabel('Days')
plt.ylabel('Close Price USD ($)')
#plt.plot(data2['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(["Valid", 'Predicted'])
plt.show()

# %% [markdown]
# # Feed Forword Neural Network

# %%
train1 = data.iloc[:training_data_len]
test1 = data.iloc[training_data_len:]
features = ['Close']

# %%
X_train5 = train1[features]
y_train2 = train1['Adj Close']
X_test5 = test1[features]
y_test = test1['Adj Close']

# %%
from sklearn import preprocessing
from keras import optimizers
X_train5 = preprocessing.normalize(X_train5)
X_test5 = preprocessing.normalize(X_test5)

# %%
X_train5=X_train5.astype(float)
y_train2=y_train2.astype(float)
X_test5=X_test5.astype(float)

# %%
X_train5
# Out:
# array([[1.],
#        [1.],
#        [1.],
#        ...,
#        [1.],
#        [1.],
#        [1.]])

# %%
model = Sequential()
model.add(Dense(units=100, input_dim=2,activation="relu",kernel_initializer="random_uniform",input_shape=(None, 100, 1)))
model.add(Dropout(0.30))
model.add(Dense(units=50, activation="relu", kernel_initializer="random_uniform"))
model.add(Dropout(0.10))
model.add(Dense(units=25, activation="relu", kernel_initializer="random_uniform"))
model.add(Dropout(0.05))
model.add(Dense(units=2, activation="sigmoid"))

# %%
model.compile(loss="binary_crossentropy",optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, None, 100, 100)    200
#
#  dropout_11 (Dropout)        (None, None, 100, 100)    0
#
#  dense_12 (Dense)            (None, None, 100, 50)     5050
#
#  dropout_12 (Dropout)        (None, None, 100, 50)     0
#
#  dense_13 (Dense)            (None, None, 100, 25)     1275
#
#  dropout_13 (Dropout)        (None, None, 100, 25)     0
#
#  dense_14 (Dense)            (None, None, 100, 2)      52
#
# =================================================================
# Total params: 6,577
# Trainable params: 6,577
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train5, y_train2, epochs=10, batch_size=200, verbose=2)
# Out:
# Epoch 1/10
# WARNING:tensorflow:Model was constructed with shape (None, None, 100, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 100, 1), dtype=tf.float32, name='dense_11_input'), name='dense_11_input', description="created by layer 'dense_11_input'"), but it was called on an input with incompatible shape (None, 1).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\DAVIDN~1\AppData\Local\Temp/ipykernel_6476/3707917552.py in <module>
# ----> 1 model.fit(X_train5, y_train2, epochs=10, batch_size=200, verbose=2)
#
# D:\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# D:\anaconda3\lib\site-packages\keras\engine\training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "D:\anaconda3\lib\site-packages\keras\engine\training.py", line 1051, in train_function  *
#         return step_function(self, iterator)
#     File "D:\anaconda3\lib\site-packages\keras\engine\training.py", line 1040, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "D:\anaconda3\lib\site-packages\keras\engine\training.py", line 1030, in run_step  **
#         outputs = model.train_step(data)
#     File "D:\anaconda3\lib\site-packages\keras\engine\training.py", line 890, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "D:\anaconda3\lib\site-packages\keras\engine\training.py", line 948, in compute_loss
#         return self.compiled_loss(
#     File "D:\anaconda3\lib\site-packages\keras\engine\compile_utils.py", line 201, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "D:\anaconda3\lib\site-packages\keras\losses.py", line 139, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "D:\anaconda3\lib\site-packages\keras\losses.py", line 243, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "D:\anaconda3\lib\site-packages\keras\losses.py", line 1930, in binary_crossentropy
#         backend.binary_crossentropy(y_true, y_pred, from_logits=from_logits),
#     File "D:\anaconda3\lib\site-packages\keras\backend.py", line 5283, in binary_crossentropy
#         return tf.nn.sigmoid_cross_entropy_with_logits(labels=target, logits=output)
#
#     ValueError: `logits` and `labels` must have the same shape, received ((None, 2) vs (None, 1)).

# %%
model.evaluate(X_test5, y_test)

# %%
closing_price3 = model.predict(X_test5)
closing_price3 = scalar.inverse_transform(closing_price3)

# %%
rms=np.sqrt(np.mean(np.power((valid-closing_price3),2)))
rms

# %%
valid['Predictions'] = closing_price3

# %%
plt.figure(figsize=(16,8))
plt.title("Feed Forward Model")
plt.xlabel('Days')
plt.ylabel('Close Price USD ($)')
plt.plot(data2['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(["Original", "Valid", 'Predicted'])
plt.show()

# %% [markdown]
# # Decision Trees

# %%
data3 = data2['Close']
data3
# Out:
# 0         0.513393
# 1         0.486607
# 2         0.450893
# 3         0.462054
# 4         0.475446
#            ...
# 9904    258.440002
# 9905    247.740005
# 9906    254.809998
# 9907    254.289993
# 9908    240.910004
# Name: Close, Length: 9909, dtype: float64

# %%
data3 = pd.DataFrame(data3)

# %%
future_days = 100
data3['Prediction'] = data3['Close'].shift(-future_days)

# %%
X = np.array(data3.drop(['Prediction'], 1))[:-future_days]
print(X)
# Out:
# [[  0.51339287]
#  [  0.48660713]
#  [  0.45089287]
#  ...
#  [257.5       ]
#  [257.13000488]
#  [257.23999023]]
# C:\Users\DAVIDN~1\AppData\Local\Temp/ipykernel_6476/3239687401.py:1: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
y = np.array(data3['Prediction'])[:-future_days]
print(y)
# Out:
# [  0.4955357    0.5          0.4888393  ... 254.80999756 254.28999329
#  240.91000366]

# %%
X_train6, X_test6, y_train6, y_test6 = train_test_split(X, y, test_size = 0.2)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree

# %%
model= DecisionTreeRegressor()

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\DAVIDN~1\AppData\Local\Temp/ipykernel_6476/3470139634.py in <module>
# ----> 1 model.summary()
#
# AttributeError: 'DecisionTreeRegressor' object has no attribute 'summary'

# %%
model.fit(X_train6, y_train6)
# Out:
# DecisionTreeRegressor()

# %%
x_future = data3.drop(['Prediction'], 1)[:-future_days]
x_future = x_future.tail(future_days)
x_future = np.array(x_future)
# Out:
# C:\Users\DAVIDN~1\AppData\Local\Temp/ipykernel_6476/2191783318.py:1: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
tree_prediction = model.predict(x_future)
print(tree_prediction)
# Out:
# [259.42999268 266.29000854 262.20001221 261.95999146 264.47000122
#  262.64001465 265.76000977 267.1000061  266.29000854 194.02000427
#  262.01000977 261.77999878 266.36999512 264.29000854 267.83999634
#  267.25       264.16000366 259.45001221 261.73999023 265.57998657
#  270.70999146 266.92001343 268.48001099 270.76998901 271.45999146
#  275.1499939  279.85998535 280.41000366 317.69000244 280.01998901
#  323.86999512 284.         284.26998901 212.24000549 205.52999878
#  291.51998901 293.6499939  267.83999634 297.42999268 299.79998779
#  298.39001465 303.19000244 309.63000488 310.32998657 316.95999146
#  312.67999268 311.33999634 315.23999023 318.73001099 316.57000732
#  317.70001221 319.23001099 318.30999756 308.95001221 317.69000244
#  324.33999634 323.86999512 309.51000977 308.66000366 318.8500061
#  321.45001221 324.95001221 320.02999878 321.54998779 319.60998535
#  327.20001221 324.86999512 324.95001221 319.         323.61999512
#  320.29998779 313.04998779 298.17999268 288.07998657 292.6499939
#  273.51998901 273.35998535 298.80999756 289.32000732 273.35998535
#  292.92001343 289.02999878 289.02999878 285.33999634 275.42999268
#  248.22999573 277.97000122 242.21000671 252.86000061 246.88000488
#  244.77999878 229.24000549 224.36999512 246.88000488 246.88000488
#  224.36999512 247.74000549 254.80999756 240.91000366 240.91000366]

# %%
predictions = tree_prediction 
valid = data3[X.shape[0]:]
valid['Predictions'] = predictions
# Out:
# C:\Users\DAVIDN~1\AppData\Local\Temp/ipykernel_6476/1510866107.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plt.figure(figsize=(16,8))
plt.title("Decision Tree Model")
plt.xlabel('Days')
plt.ylabel('Close Price USD ($)')
plt.plot(data3['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(["Original", "Valid", 'Predicted'])
plt.show()

# %% [markdown]
# # Linear and Logistic Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\DAVIDN~1\AppData\Local\Temp/ipykernel_6476/3470139634.py in <module>
# ----> 1 model.summary()
#
# AttributeError: 'LinearRegression' object has no attribute 'summary'

# %%
model.fit(X_train6, y_train6)
# Out:
# LinearRegression()

# %%
x_future = data3.drop(['Prediction'], 1)[:-future_days]
x_future = x_future.tail(future_days)
x_future = np.array(x_future)
x_future
# Out:
# C:\Users\DAVIDN~1\AppData\Local\Temp/ipykernel_6476/1128973448.py:1: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# array([[198.44999695],
#        [197.86999512],
#        [199.46000671],
#        [198.77999878],
#        [198.58000183],
#        [195.57000732],
#        [199.80000305],
#        [199.74000549],
#        [197.91999817],
#        [201.55000305],
#        [202.72999573],
#        [204.41000366],
#        [204.22999573],
#        [200.02000427],
#        [201.24000549],
#        [203.22999573],
#        [201.75      ],
#        [203.30000305],
#        [205.21000671],
#        [204.5       ],
#        [203.3500061 ],
#        [205.66000366],
#        [202.58999634],
#        [207.22000122],
#        [208.83999634],
#        [208.66999817],
#        [207.02000427],
#        [207.74000549],
#        [209.67999268],
#        [208.77999878],
#        [213.03999329],
#        [208.42999268],
#        [204.02000427],
#        [193.33999634],
#        [197.        ],
#        [199.03999329],
#        [203.42999268],
#        [200.99000549],
#        [200.47999573],
#        [208.97000122],
#        [202.75      ],
#        [201.74000549],
#        [206.5       ],
#        [210.3500061 ],
#        [210.36000061],
#        [212.63999939],
#        [212.46000671],
#        [202.63999939],
#        [206.49000549],
#        [204.16000366],
#        [205.52999878],
#        [209.00999451],
#        [208.74000549],
#        [205.69999695],
#        [209.19000244],
#        [213.27999878],
#        [213.25999451],
#        [214.16999817],
#        [216.69999695],
#        [223.58999634],
#        [223.08999634],
#        [218.75      ],
#        [219.8999939 ],
#        [220.69999695],
#        [222.77000427],
#        [220.96000671],
#        [217.72999573],
#        [218.72000122],
#        [217.67999268],
#        [221.02999878],
#        [219.88999939],
#        [218.82000732],
#        [223.97000122],
#        [224.58999634],
#        [218.96000671],
#        [220.82000732],
#        [227.00999451],
#        [227.05999756],
#        [224.3999939 ],
#        [227.02999878],
#        [230.08999634],
#        [236.21000671],
#        [235.86999512],
#        [235.32000732],
#        [234.36999512],
#        [235.27999878],
#        [236.41000366],
#        [240.50999451],
#        [239.96000671],
#        [243.17999268],
#        [243.58000183],
#        [246.58000183],
#        [249.05000305],
#        [243.28999329],
#        [243.25999451],
#        [248.75999451],
#        [255.82000732],
#        [257.5       ],
#        [257.13000488],
#        [257.23999023]])

# %%
lr_prediction = model.predict(x_future)
print(lr_prediction)
# Out:
# [217.2417871  216.60732951 218.34662562 217.60277246 217.38399801
#  214.09139829 218.71854385 218.65291319 216.6620273  220.63284951
#  221.92363045 223.76137256 223.56446387 218.95920076 220.2937466
#  222.47057492 220.85162396 222.54715516 224.63648705 223.85981855
#  222.60185295 225.12873374 221.77048667 226.83519782 228.60729257
#  228.42133345 226.61642337 227.40402474 229.52615528 228.5416619
#  233.2016228  228.15879409 223.33475654 211.65201393 215.65565147
#  217.88717757 222.68934937 220.02027437 219.46238032 228.74950347
#  221.9455129  220.84069108 226.04759644 230.25907556 230.27000844
#  232.7640739  232.5671819  221.82518445 226.03666356 223.48790032
#  224.98652283 228.79325169 228.49791369 225.17248195 228.99016038
#  233.46416215 233.4422797  234.43772264 237.20526034 244.7421545
#  244.19521003 239.44773601 240.70570162 241.58081612 243.84517424
#  241.86523792 238.33196462 239.41492068 238.27726683 241.94180147
#  240.69476874 239.52431625 245.15783764 245.83604344 239.67746004
#  241.71209414 248.48325269 248.53795047 245.62820187 248.50513514
#  251.85243264 258.54704433 258.1751094  257.57348384 256.53427598
#  257.52971893 258.76581878 263.25075344 262.64912787 266.17143491
#  266.60900051 269.89066734 272.59257437 266.29176337 266.25894803
#  272.27533723 279.9982072  281.83593261 281.43119904 281.5515108 ]

# %%
predictions = lr_prediction 
valid = data3[X.shape[0]:]
valid['Predictions'] = predictions
# Out:
# C:\Users\DAVIDN~1\AppData\Local\Temp/ipykernel_6476/540213385.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plt.figure(figsize=(16,8))
plt.title("Linear Regression Model")
plt.xlabel('Days')
plt.ylabel('Close Price USD ($)')
plt.plot(data3['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(["Original", "Valid", 'Predicted'])
plt.show()

# %%
from sklearn. preprocessing import StandardScaler
scalar = StandardScaler()
X_train7 = scalar.fit_transform(X_train6)
X_test7 = scalar.transform(X_test6)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\DAVIDN~1\AppData\Local\Temp/ipykernel_6476/3470139634.py in <module>
# ----> 1 model.summary()
#
# AttributeError: 'LogisticRegression' object has no attribute 'summary'

# %%
from sklearn import preprocessing
lab = preprocessing.LabelEncoder()
y_transformed = lab.fit_transform(y_train6)

# %%
model.fit(X_train7, y_transformed)
# Out:
# LogisticRegression()

# %%
x_future = data3.drop(['Prediction'], 1)[:-future_days]
x_future = x_future.tail(future_days)
x_future = np.array(x_future)
x_future
# Out:
# C:\Users\DAVIDN~1\AppData\Local\Temp/ipykernel_6476/1128973448.py:1: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# array([[198.44999695],
#        [197.86999512],
#        [199.46000671],
#        [198.77999878],
#        [198.58000183],
#        [195.57000732],
#        [199.80000305],
#        [199.74000549],
#        [197.91999817],
#        [201.55000305],
#        [202.72999573],
#        [204.41000366],
#        [204.22999573],
#        [200.02000427],
#        [201.24000549],
#        [203.22999573],
#        [201.75      ],
#        [203.30000305],
#        [205.21000671],
#        [204.5       ],
#        [203.3500061 ],
#        [205.66000366],
#        [202.58999634],
#        [207.22000122],
#        [208.83999634],
#        [208.66999817],
#        [207.02000427],
#        [207.74000549],
#        [209.67999268],
#        [208.77999878],
#        [213.03999329],
#        [208.42999268],
#        [204.02000427],
#        [193.33999634],
#        [197.        ],
#        [199.03999329],
#        [203.42999268],
#        [200.99000549],
#        [200.47999573],
#        [208.97000122],
#        [202.75      ],
#        [201.74000549],
#        [206.5       ],
#        [210.3500061 ],
#        [210.36000061],
#        [212.63999939],
#        [212.46000671],
#        [202.63999939],
#        [206.49000549],
#        [204.16000366],
#        [205.52999878],
#        [209.00999451],
#        [208.74000549],
#        [205.69999695],
#        [209.19000244],
#        [213.27999878],
#        [213.25999451],
#        [214.16999817],
#        [216.69999695],
#        [223.58999634],
#        [223.08999634],
#        [218.75      ],
#        [219.8999939 ],
#        [220.69999695],
#        [222.77000427],
#        [220.96000671],
#        [217.72999573],
#        [218.72000122],
#        [217.67999268],
#        [221.02999878],
#        [219.88999939],
#        [218.82000732],
#        [223.97000122],
#        [224.58999634],
#        [218.96000671],
#        [220.82000732],
#        [227.00999451],
#        [227.05999756],
#        [224.3999939 ],
#        [227.02999878],
#        [230.08999634],
#        [236.21000671],
#        [235.86999512],
#        [235.32000732],
#        [234.36999512],
#        [235.27999878],
#        [236.41000366],
#        [240.50999451],
#        [239.96000671],
#        [243.17999268],
#        [243.58000183],
#        [246.58000183],
#        [249.05000305],
#        [243.28999329],
#        [243.25999451],
#        [248.75999451],
#        [255.82000732],
#        [257.5       ],
#        [257.13000488],
#        [257.23999023]])

# %%
LogR_prediction = model.predict(x_future)
print(LogR_prediction)
# Out:
# [4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438
#  4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438
#  4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438
#  4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438
#  4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438
#  4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438
#  4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438 4438
#  4438 4438]

# %%
predictions = LogR_prediction 
valid = data3[X.shape[0]:]
valid['Predictions'] = predictions
# Out:
# C:\Users\DAVIDN~1\AppData\Local\Temp/ipykernel_6476/3154835259.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plt.figure(figsize=(16,8))
plt.title("Logistic Regression Model")
plt.xlabel('Days')
plt.ylabel('Close Price USD ($)')
plt.plot(data3['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(["Original", "Valid", 'Predicted'])
plt.show()

# %% [markdown]
# # Time Series Algorithms

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=100)

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\DAVIDN~1\AppData\Local\Temp/ipykernel_6476/3470139634.py in <module>
# ----> 1 model.summary()
#
# AttributeError: 'RandomForestClassifier' object has no attribute 'summary'

# %%
model.fit(X_train6, y_transformed)

# %%
x_future = data3.drop(['Prediction'], 1)[:-future_days]
x_future = x_future.tail(future_days)
x_future = np.array(x_future)
x_future

# %%
time_series_prediction = model.predict(x_future)
print(time_series_prediction)

# %%
predictions = time_series_prediction 
valid = data3[X.shape[0]:]
valid['Predictions'] = predictions

# %%
plt.figure(figsize=(16,8))
plt.title("Time-series Model")
plt.xlabel('Days')
plt.ylabel('Close Price USD ($)')
plt.plot(data3['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(["Original", "Valid", 'Predicted'])
plt.show()

# %% [markdown]
# # Naïve Bayes Classifier

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
model=MultinomialNB(alpha=1.0)

# %%
model.summary()

# %%
model.fit(X_train6, y_transformed)

# %%
x_future = data3.drop(['Prediction'], 1)[:-future_days]
x_future = x_future.tail(future_days)
x_future = np.array(x_future)
x_future

# %%
Naive_Bayes_prediction = model.predict(x_future)
print(Naive_Bayes_prediction)

# %%
predictions = Naive_Bayes_prediction 
valid = data3[X.shape[0]:]
valid['Predictions'] = predictions

# %%
plt.figure(figsize=(16,8))
plt.title("Naive-Bayes Model")
plt.xlabel('Days')
plt.ylabel('Close Price USD ($)')
plt.plot(data3['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(["Original", "Valid", 'Predicted'])
plt.show()

# %% [markdown]
# # Support Vector Machines

# %%
from sklearn.svm import SVC
from sklearn import preprocessing

# %%
lab = preprocessing.LabelEncoder()
y_transformed = lab.fit_transform(y_train6)

# %%
model = SVC()

# %%
model.summary()

# %%
model.fit(X_train6, y_transformed)

# %%
x_future = data3.drop(['Prediction'], 1)[:-future_days]
x_future = x_future.tail(future_days)
x_future = np.array(x_future)
x_future

# %%
svc_prediction = model.predict(x_future)
print(svc_prediction)

# %%
predictions = svc_prediction 
valid = data3[X.shape[0]:]
valid['Predictions'] = predictions

# %%
plt.figure(figsize=(16,8))
plt.title("SVM Model")
plt.xlabel('Days')
plt.ylabel('Close Price USD ($)')
plt.plot(data3['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(["Original", "Valid", 'Predicted'])
plt.show()

# %% [markdown]
# # The End
